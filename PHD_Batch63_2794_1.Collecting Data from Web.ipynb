# %% [markdown]
# # PHD: Sentiment Analysis on Lion King Movie Review (2019)

# %% [markdown]
# ### What is Sentiment Analysis ?
#
# - Sentiment Analysis is basically concerned with analysis of emotions and opinions from text. We can refer sentiment analysis as opinion mining. Sentiment analysis finds and justifies the sentiment of the person with respect to a given source of content.
#
#
# - In today's virtual world, as everything is connected to internet one can easily form an opinion about the certain thing and express it. This acts as a litmus test for many companies who depend on people opinion to sell their product(s).

# %% [markdown]
# ### Problem Statement:
#
# - Moview Reviews are important for the production house to get an idea about how the movie is been recieved by the auidence. As more than 90% of people book movie tickets online, analysing the reviews and ratings will give a clear idea and popularity of the movie.
#
#
# - Gather the reviews of the latest movie " The Lion King" from the online ticketing site "Rotten Tomatoes" and perform sentiment analysis on the reviews such that it will give clear picture about the opinion of the people on the movie and the production house will be able to tackle the "negative" reviews to  control damage.

# %% [markdown]
# ### Tasks to be performed:

# %% [markdown]
# 1. Collect Audience reviews from "www.rottentomatoes.com" for the film: “The Lion King (2019)”
#
# 2. Label the Review "sentiment" (Target). ( Rating >3 as "Positive" and Rating <3 as "Negative" )
#
# 3. Perform the Visualizations & EDA on the data gathered.
#
# 4. Perform Sentiment Classification using supervised learning
#
# 5. Clustering the Reviews – Comparing ‘Cluster Label’ with Train data Target ‘sentiment’

# %% [markdown]
# ### Web Scrapping and Collecting Data

# %% [markdown]
# - Collect 3000 reviews from the "Rotten Tomatoes" website (live)

# %%
#Load the libraries
#!pip install requests
import requests
import time 
import pandas as pd
import numpy as  np

# %%
#Create a header for the request.

headers = {
    'Referer': 'https://www.rottentomatoes.com/m/the_lion_king_2019/reviews?type=user',     
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.108 Safari/537.36',    
    'X-Requested-With': 'XMLHttpRequest',
          }

# %%
#Mention the URL details.
url = 'https://www.rottentomatoes.com/napi/movie/9057c2cf-7cab-317f-876f-e50b245ca76e/reviews/user' 

#Create the session object
session_object = requests.Session()

# %%
#We need to gather the data for 3000 reviews and each page has 10 reviews. So to gather the data from 300 pages,
#call everything in a loop.

all_reviews = []
end_cursor = ''
start_cursor = ''

# Fetch the data using GET from the mentioned URL using the parameters for 300 pages

for index in range(300):
    payload = {'direction':'next','endCursor':end_cursor,'startCursor':start_cursor} #Set the Parameters
    time.sleep(5) 
    r= session_object.get(url, params=payload, headers=headers)    # GET Call 
    data = r.json()
    all_reviews = all_reviews + data['reviews']
    end_cursor = data['pageInfo']['endCursor']
    start_cursor = data['pageInfo']['startCursor']

all_reviews
# Out:
# [{'rating': 'STAR_5',
#   'review': 'I liked most that the animation made the animals look so real',
#   'displayName': 'Joanne H',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T08:54:30.664Z',
#   'updateDate': '2019-08-18T08:54:30.890Z',
#   'user': {'userId': '2c73ed20-5b9f-41b3-a4fd-8dd3ff8bb20a',
#    'realm': 'Fandango',
#    'displayName': 'Joanne H',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '31m ago'},
#  {'rating': 'STAR_5',
#   'review': 'Amazing! So realistic and incredible music',
#   'displayName': 'Frankie C',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/594379764/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T08:03:49.380Z',
#   'updateDate': '2019-08-18T08:03:49.380Z',
#   'user': {'userId': '871398953',
#    'realm': 'RT',
#    'displayName': 'Frankie C',
#    'accountLink': '/user/id/871398953'},
#   'score': 5,
#   'timeFromCreation': '1h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Classic. Good remake. Loved it. Glover was outstanding',
#   'displayName': 'jaycee',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T07:13:32.422Z',
#   'updateDate': '2019-08-18T07:13:32.422Z',
#   'user': {'userId': 'DD2453B0-37CE-4B47-A099-D15378FC310E',
#    'realm': 'Fandango',
#    'displayName': 'jaycee',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '2h ago'},
#  {'rating': 'STAR_2',
#   'review': 'Nice animation/CGI but completely lacking the "Disney" style humour and wonder of the original.  Undue concentration on violence scared the kiddies.  The real question is "Why?"',
#   'displayName': 'Peter A',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/100000479373060/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T07:06:08.698Z',
#   'updateDate': '2019-08-18T07:06:46.610Z',
#   'user': {'userId': '906750266',
#    'realm': 'RT',
#    'displayName': 'Peter A',
#    'accountLink': '/user/id/906750266'},
#   'score': 2,
#   'timeFromCreation': '2h ago'},
#  {'rating': 'STAR_4',
#   'review': 'Good but go mainly for the sentimental value',
#   'displayName': 'Kevin M',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T06:38:46.892Z',
#   'updateDate': '2019-08-18T06:38:46.892Z',
#   'user': {'userId': '21FE7D93-351C-43B5-833D-B1DB11F3FD6A',
#    'realm': 'Fandango',
#    'displayName': 'Kevin M',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '3h ago'},
#  {'rating': 'STAR_4',
#   'review': 'The animation was really good',
#   'displayName': 'Angelwolf',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T05:34:19.360Z',
#   'updateDate': '2019-08-18T05:34:19.360Z',
#   'user': {'userId': 'E62CDAD2-329A-4924-8455-35249C3BCC4D',
#    'realm': 'Fandango',
#    'displayName': 'Angelwolf',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '4h ago'},
#  {'rating': 'STAR_5',
#   'review': 'i thought it was awesone. i really like the originalaty of the animals.really enjoyed it .i would see it again.  they nailed it .cant wait till dvd comes out .very much worth it',
#   'displayName': 'sheril',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T05:22:03.783Z',
#   'updateDate': '2019-08-18T05:22:03.783Z',
#   'user': {'userId': '8229f609-93a7-4c8e-8ec7-37b18fa65679',
#    'realm': 'Fandango',
#    'displayName': 'sheril',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '4h ago'},
#  {'rating': 'STAR_3',
#   'review': 'I think that they should’ve brought back more of the original voice actors, This movie is so iconic and So important to so many people... I don’t think they did it any justice the way it is.  If they had created an entirely new story with the kind of computer generated animals that were in the lion King they would have had an amazing movie but, the way it is now it was kind of disappointing',
#   'displayName': 'Maggie L',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T05:14:42.958Z',
#   'updateDate': '2019-08-18T05:14:42.958Z',
#   'user': {'userId': '8B9ED608-C9C6-4EAF-82A3-1DF9FFFD0EA4',
#    'realm': 'Fandango',
#    'displayName': 'Maggie L',
#    'accountLink': None},
#   'score': 3,
#   'timeFromCreation': '4h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Great, absolutely great!  The animation was great, the story line spot on and Beyoncé delivered.  A little more violence than the animated version but that was expected.  Overall - loved it.',
#   'displayName': 'Bryan A',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T04:58:59.214Z',
#   'updateDate': '2019-08-18T04:58:59.214Z',
#   'user': {'userId': 'C792B3A4-EC33-48C2-A911-A2AAB946B94F',
#    'realm': 'Fandango',
#    'displayName': 'Bryan A',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '4h ago'},
#  {'rating': 'STAR_5',
#   'review': 'It was just like the first one. Very good animation. Very cute movie',
#   'displayName': 'Bethany',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T04:51:44.361Z',
#   'updateDate': '2019-08-18T04:51:44.361Z',
#   'user': {'userId': '45c8dfaa-e20f-44df-8f01-445c0f055e42',
#    'realm': 'Fandango',
#    'displayName': 'Bethany',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '5h ago'},
#  {'rating': 'STAR_3',
#   'review': "Didn't make me feel anything unlike the original.",
#   'displayName': 'Alexander G',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T04:35:16.243Z',
#   'updateDate': '2019-08-18T04:35:16.243Z',
#   'user': {'userId': '978203293',
#    'realm': 'RT',
#    'displayName': 'Alexander G',
#    'accountLink': '/user/id/978203293'},
#   'score': 3,
#   'timeFromCreation': '5h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Well done! A great way to redo a classic. It felt part National Geographic, part Pixar. Loved watching all of the animal species in their habitat.',
#   'displayName': 'Lori',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T04:10:11.153Z',
#   'updateDate': '2019-08-18T04:10:11.153Z',
#   'user': {'userId': '8ce21b61-d2b1-453e-ab78-fe0ba06088d5',
#    'realm': 'Fandango',
#    'displayName': 'Lori',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '5h ago'},
#  {'rating': 'STAR_4',
#   'review': 'Good movie.  Just that the original animated was better, in my humble opinion.',
#   'displayName': 'Tim stoeckle',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T03:39:22.555Z',
#   'updateDate': '2019-08-18T03:39:22.555Z',
#   'user': {'userId': '4e4abb87-64d4-4f65-8673-8e0b9b612c1b',
#    'realm': 'Fandango',
#    'displayName': 'Tim stoeckle',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '6h ago'},
#  {'rating': 'STAR_3',
#   'review': 'I didn’t like Beyoncé being nala. Bad acting. I didn’t like that they kept some things out. I didn’t like some of the stuff that they added was unnecessary. It’s a very good classic no need to try to fix or change something that is very nostalgic to childhood memories. So for me it was more of a 2.5 rating.',
#   'displayName': 'Sheena',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T03:28:50.700Z',
#   'updateDate': '2019-08-18T03:28:50.700Z',
#   'user': {'userId': 'C211508E-B600-44E0-A289-C43EEDF30831',
#    'realm': 'Fandango',
#    'displayName': 'Sheena',
#    'accountLink': None},
#   'score': 3,
#   'timeFromCreation': '6h ago'},
#  {'rating': 'STAR_5',
#   'review': "Such a beautiful story. We've loved the animated version for years, but this was a step up. The animals were all so beautiful, except the hyenas, which were really scary!",
#   'displayName': 'Marsha C',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T03:25:45.583Z',
#   'updateDate': '2019-08-18T03:25:45.583Z',
#   'user': {'userId': '9c220502-046b-4b98-a0d1-ad271ed611f8',
#    'realm': 'Fandango',
#    'displayName': 'Marsha C',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '6h ago'},
#  {'rating': 'STAR_4',
#   'review': 'great Flick, Kids had some good Laughs,.',
#   'displayName': 'Rigo',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T03:25:08.042Z',
#   'updateDate': '2019-08-18T03:25:08.042Z',
#   'user': {'userId': 'E5B8CCF8-F6B5-4ACD-B1AC-D7736129DB0C',
#    'realm': 'Fandango',
#    'displayName': 'Rigo',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '6h ago'},
#  {'rating': 'STAR_5',
#   'review': 'It was great!! We loved it.',
#   'displayName': 'Eckj',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T03:15:54.657Z',
#   'updateDate': '2019-08-18T03:15:54.657Z',
#   'user': {'userId': '75b78309-78b8-4670-8cef-26693359f0ab',
#    'realm': 'Fandango',
#    'displayName': 'Eckj',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '6h ago'},
#  {'rating': 'STAR_4_5',
#   'review': 'It’s The Lion King! This movie is absolutely gorgeous. Every little detail was thought of and shown in this movie. From the soundtrack to the story it’ll take you right back to the first time you saw it when you were a kid.',
#   'displayName': 'Chandler',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T03:15:48.253Z',
#   'updateDate': '2019-08-18T03:15:48.253Z',
#   'user': {'userId': 'D6FAE8CA-89D2-49FD-8DFE-90ECCD197DF6',
#    'realm': 'Fandango',
#    'displayName': 'Chandler',
#    'accountLink': None},
#   'score': 4.5,
#   'timeFromCreation': '6h ago'},
#  {'rating': 'STAR_5',
#   'review': 'I truly enjoyed this movie from the story to the music. Had such a great cast',
#   'displayName': 'Jeffrey B',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T03:08:09.223Z',
#   'updateDate': '2019-08-18T03:08:09.223Z',
#   'user': {'userId': '978203215',
#    'realm': 'RT',
#    'displayName': 'Jeffrey B',
#    'accountLink': '/user/id/978203215'},
#   'score': 5,
#   'timeFromCreation': '6h ago'},
#  {'rating': 'STAR_5',
#   'review': 'All of the animals were so life-like and real!  I dont know how they do that!  WONDERFUL!  Loved it!',
#   'displayName': 'Linda Lea',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T02:30:52.219Z',
#   'updateDate': '2019-08-18T02:30:52.219Z',
#   'user': {'userId': '820a7d8b-6d22-447a-9ed9-02dc1437db87',
#    'realm': 'Fandango',
#    'displayName': 'Linda Lea',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '7h ago'},
#  {'rating': 'STAR_4',
#   'review': 'Very good movie a little violent for young kids maybe',
#   'displayName': 'Tim T',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T02:29:04.887Z',
#   'updateDate': '2019-08-18T02:29:04.887Z',
#   'user': {'userId': '7b25d789-e4e6-4eb4-9f75-500c240b5706',
#    'realm': 'Fandango',
#    'displayName': 'Tim T',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '7h ago'},
#  {'rating': 'STAR_5',
#   'review': 'awesome!!! a must see',
#   'displayName': 'ch',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T02:14:40.116Z',
#   'updateDate': '2019-08-18T02:14:40.116Z',
#   'user': {'userId': 'D91F2EBC-B1EF-4D59-BEF2-D59000B603D0',
#    'realm': 'Fandango',
#    'displayName': 'ch',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '7h ago'},
#  {'rating': 'STAR_0_5',
#   'review': 'Animation was good. Nearly every line was the exact same as the old movie though so its very boring. Besides the way the movie looks it is the exact same. Dont really understand why they remade this one. At least the Aladdin remake had some changes to the story line and new songs to keep it fresh and entertaining',
#   'displayName': 'J',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T02:07:24.616Z',
#   'updateDate': '2019-08-18T02:07:32.852Z',
#   'user': {'userId': '2406414a-397f-4d7a-affc-b0a912d2fdab',
#    'realm': 'Fandango',
#    'displayName': 'J',
#    'accountLink': None},
#   'score': 0.5,
#   'timeFromCreation': '7h ago'},
#  {'rating': 'STAR_4_5',
#   'review': 'Not the original, but just as special.',
#   'displayName': None,
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T01:43:16.296Z',
#   'updateDate': '2019-08-18T01:43:16.296Z',
#   'user': {'userId': '260314256',
#    'realm': 'RT',
#    'displayName': None,
#    'accountLink': '/user/id/260314256'},
#   'score': 4.5,
#   'timeFromCreation': '8h ago'},
#  {'rating': 'STAR_3',
#   'review': "the hype didn't meet expectations",
#   'displayName': 'sheri w',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T01:40:56.927Z',
#   'updateDate': '2019-08-18T01:40:56.927Z',
#   'user': {'userId': 'D43132C3-78D5-48D7-9A3A-F66A5038E557',
#    'realm': 'Fandango',
#    'displayName': 'sheri w',
#    'accountLink': None},
#   'score': 3,
#   'timeFromCreation': '8h ago'},
#  {'rating': 'STAR_4',
#   'review': 'While rated PG, it is most appropriate for fourth or fifth graders & up.',
#   'displayName': 'Kenneth P.',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T01:29:38.529Z',
#   'updateDate': '2019-08-18T01:29:38.529Z',
#   'user': {'userId': '1772b651-3b2d-418e-998d-cd7e588c3b2c',
#    'realm': 'Fandango',
#    'displayName': 'Kenneth P.',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '8h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Very good adaptation of the original cartoon with realistic looking animation.',
#   'displayName': 'Salsamanp',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T01:28:25.450Z',
#   'updateDate': '2019-08-18T01:28:25.450Z',
#   'user': {'userId': '219cb505-1e94-4299-9511-dafae418922a',
#    'realm': 'Fandango',
#    'displayName': 'Salsamanp',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '8h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Wonderful and pretty close to the original!',
#   'displayName': 'Jennifer',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T01:04:16.101Z',
#   'updateDate': '2019-08-18T01:04:16.101Z',
#   'user': {'userId': '9D2E9337-C3D2-4A18-8976-59C9705C0948',
#    'realm': 'Fandango',
#    'displayName': 'Jennifer',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '8h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Loved it. I loved the original cartoon so I have it a shot and tell on love.',
#   'displayName': 'SWalt',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T00:59:46.371Z',
#   'updateDate': '2019-08-18T00:59:46.371Z',
#   'user': {'userId': '20929b8f-e35e-469d-83a8-224b257e5c13',
#    'realm': 'Fandango',
#    'displayName': 'SWalt',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '8h ago'},
#  {'rating': 'STAR_4',
#   'review': 'Same history, more realist. Good work. ',
#   'displayName': 'Juan S',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T00:57:22.168Z',
#   'updateDate': '2019-08-18T00:57:22.165Z',
#   'user': {'userId': '978203088',
#    'realm': 'RT',
#    'displayName': 'Juan S',
#    'accountLink': '/user/id/978203088'},
#   'score': 4,
#   'timeFromCreation': '8h ago'},
#  {'rating': 'STAR_5',
#   'review': 'This story will never grow old....just a fresh perspective on wonderful!',
#   'displayName': 'Paula R',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T00:18:38.119Z',
#   'updateDate': '2019-08-18T00:18:38.119Z',
#   'user': {'userId': 'c06d43ca-18b3-42f7-a9bf-7e5cfb7fc39d',
#    'realm': 'Fandango',
#    'displayName': 'Paula R',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '9h ago'},
#  {'rating': 'STAR_2',
#   'review': 'I fell asleep several times.  Animated movie was so much better.',
#   'displayName': 'scouting6',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T00:14:59.136Z',
#   'updateDate': '2019-08-18T00:14:59.136Z',
#   'user': {'userId': '82FCCD42-66C4-41E7-96F7-DE3B46764B51',
#    'realm': 'Fandango',
#    'displayName': 'scouting6',
#    'accountLink': None},
#   'score': 2,
#   'timeFromCreation': '9h ago'},
#  {'rating': 'STAR_2_5',
#   'review': "VERY BEAUTIFUL. The CGI looked genuinely amazing but that's all I really have to say. The animated one was so much better. At least they brought back James Earl Jones. However SETH ROGAN should NOT have been PUMBA. I now will always picture Pumba as a stoner",
#   'displayName': 'David G',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T00:12:48.842Z',
#   'updateDate': '2019-08-18T00:12:48.842Z',
#   'user': {'userId': '978171705',
#    'realm': 'RT',
#    'displayName': 'David G',
#    'accountLink': '/user/id/978171705'},
#   'score': 2.5,
#   'timeFromCreation': '9h ago'},
#  {'rating': 'STAR_5',
#   'review': 'It was wonderful!! My family loved it! There is nothing i would change. It was perfect!!😊',
#   'displayName': 'Michelle Salazar',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T00:06:43.886Z',
#   'updateDate': '2019-08-18T00:06:43.886Z',
#   'user': {'userId': 'F73BC87D-F6D2-4F9D-A1AD-A4324462D0EC',
#    'realm': 'Fandango',
#    'displayName': 'Michelle Salazar',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '9h ago'},
#  {'rating': 'STAR_4',
#   'review': 'Very entertaining. Seth Rogan as Pumba was excellent. Please tell me how on Earth you recite “Be Prepared”?! We got jilted out of that. Also, star off because remakes involving animals don’t go over as well as humans. Aladdin allowed you to better immerse yourself, since there were humans you could connect with. I don’t think anything was gained by remaking Lion King.',
#   'displayName': 'Cet',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T23:47:09.266Z',
#   'updateDate': '2019-08-17T23:47:09.266Z',
#   'user': {'userId': 'B68B17A0-1F10-4C61-9D29-A3EE48822C4B',
#    'realm': 'Fandango',
#    'displayName': 'Cet',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '10h ago'},
#  {'rating': 'STAR_4_5',
#   'review': 'Greatest adaptation!!!',
#   'displayName': 'Charles Ward',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T23:37:13.441Z',
#   'updateDate': '2019-08-17T23:37:13.441Z',
#   'user': {'userId': '8A06AC36-221D-426F-A117-45BEAD96C09E',
#    'realm': 'Fandango',
#    'displayName': 'Charles Ward',
#    'accountLink': None},
#   'score': 4.5,
#   'timeFromCreation': '10h ago'},
#  {'rating': 'STAR_3_5',
#   'review': "I don't know what to feel about this movie.\nI was waiting to see it since it was announced that it was going out, I saw the trailer and the emotion was great but at the moment of seeing it the feeling was different. I felt that it was not what I expected.\nI will not deny that the effects and the music were incredible, but I do not know why but the plot did not convince me. I felt that I had seen another movie and not THE LION KING.\nIt would have been nice if this movie would have looked a little closer to the original. I think that I would have enjoyed it more.\nI can say that I liked it but I did not enjoy it at all.",
#   'displayName': 'Claudia C',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T23:21:09.548Z',
#   'updateDate': '2019-08-17T23:21:09.548Z',
#   'user': {'userId': '978202971',
#    'realm': 'RT',
#    'displayName': 'Claudia C',
#    'accountLink': '/user/id/978202971'},
#   'score': 3.5,
#   'timeFromCreation': '10h ago'},
#  {'rating': 'STAR_4_5',
#   'review': "I really liked this remake of the Disney Classic.  I didn't like how the movie changed certain iconic aspects of the original. Overall though, the movie was basically the exact same as the original and also includes a few extra scenes that help to tell the story.  I would definitely go see this before it leaves theaters!",
#   'displayName': 'Google',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T23:06:14.086Z',
#   'updateDate': '2019-08-17T23:06:14.086Z',
#   'user': {'userId': '7af5a466-5e13-4dea-84e6-3d28403f02d2',
#    'realm': 'Fandango',
#    'displayName': 'Google',
#    'accountLink': None},
#   'score': 4.5,
#   'timeFromCreation': '10h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Great performances and altogether recreation',
#   'displayName': 'Shamontae',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T22:58:31.474Z',
#   'updateDate': '2019-08-17T22:58:31.474Z',
#   'user': {'userId': '3cca24e6-e906-4d4e-bff5-641f546314c9',
#    'realm': 'Fandango',
#    'displayName': 'Shamontae',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '10h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Great movie for the kids.',
#   'displayName': 'Angel',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T22:52:20.114Z',
#   'updateDate': '2019-08-17T22:52:20.114Z',
#   'user': {'userId': 'C1CEC4B4-575E-4030-B4C8-B77CECFF19D3',
#    'realm': 'Fandango',
#    'displayName': 'Angel',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '11h ago'},
#  {'rating': 'STAR_4_5',
#   'review': 'Fulfilled my nostalgia',
#   'displayName': 'Ellena',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T22:42:15.647Z',
#   'updateDate': '2019-08-17T22:42:15.647Z',
#   'user': {'userId': '091629A5-E372-4164-BDC3-16BEB6D1CF2F',
#    'realm': 'Fandango',
#    'displayName': 'Ellena',
#    'accountLink': None},
#   'score': 4.5,
#   'timeFromCreation': '11h ago'},
#  {'rating': 'STAR_2',
#   'review': 'Hated that it was different that original',
#   'displayName': 'Heidi L',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T22:32:28.679Z',
#   'updateDate': '2019-08-17T22:32:28.679Z',
#   'user': {'userId': '9D7FC189-CD94-404D-9F2C-F1A42FF4AF41',
#    'realm': 'Fandango',
#    'displayName': 'Heidi L',
#    'accountLink': None},
#   'score': 2,
#   'timeFromCreation': '11h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Loved the special affects',
#   'displayName': 'Lenora',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T22:18:43.032Z',
#   'updateDate': '2019-08-17T22:18:43.032Z',
#   'user': {'userId': '0EC70ECD-F63E-4ACD-ABF7-C3D983B56AA6',
#    'realm': 'Fandango',
#    'displayName': 'Lenora',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '11h ago'},
#  {'rating': 'STAR_3',
#   'review': 'Not much humor. Not even close to as good as the original. I had high hopes after watching the Jungle Book remake by this director. Just seemed uninspired. It had pretty good CGI however.',
#   'displayName': 'Ted',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T22:04:48.038Z',
#   'updateDate': '2019-08-17T22:04:48.038Z',
#   'user': {'userId': 'C7AA7076-7B30-4882-859E-9BBCF727D49D',
#    'realm': 'Fandango',
#    'displayName': 'Ted',
#    'accountLink': None},
#   'score': 3,
#   'timeFromCreation': '11h ago'},
#  {'rating': 'STAR_5',
#   'review': 'It was amazing. Best Disney remake!',
#   'displayName': 'Alyssa',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T21:49:44.181Z',
#   'updateDate': '2019-08-17T21:49:44.181Z',
#   'user': {'userId': '93717EC0-2BBB-4D7E-B379-1317E137BA80',
#    'realm': 'Fandango',
#    'displayName': 'Alyssa',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '12h ago'},
#  {'rating': 'STAR_5',
#   'review': 'great movie just like the original',
#   'displayName': 'cindy',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T21:18:39.378Z',
#   'updateDate': '2019-08-17T21:18:39.378Z',
#   'user': {'userId': 'D641A434-A130-484A-BEC8-FD95FFE6CA62',
#    'realm': 'Fandango',
#    'displayName': 'cindy',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '12h ago'},
#  {'rating': 'STAR_5',
#   'review': 'of all the new Disney remakes, this was by far my favorite one!',
#   'displayName': 'Madeleine',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T21:17:37.894Z',
#   'updateDate': '2019-08-17T21:17:37.894Z',
#   'user': {'userId': 'D47EE08C-77C9-46D5-94E9-7B5E765FFA6E',
#    'realm': 'Fandango',
#    'displayName': 'Madeleine',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '12h ago'},
#  {'rating': 'STAR_3',
#   'review': 'It was fine. Basically a shot for shot remake of the original without the fun and emotion. This won’t be replacing the animated version in our viewing list.',
#   'displayName': 'nora',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T21:13:25.779Z',
#   'updateDate': '2019-08-17T21:13:25.779Z',
#   'user': {'userId': 'A70EC39F-D8BB-4249-9635-4AF4DAAC0C52',
#    'realm': 'Fandango',
#    'displayName': 'nora',
#    'accountLink': None},
#   'score': 3,
#   'timeFromCreation': '12h ago'},
#  {'rating': 'STAR_5',
#   'review': "Go and see it. It's worth it",
#   'displayName': 'KrisP',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T20:52:39.008Z',
#   'updateDate': '2019-08-17T20:52:39.008Z',
#   'user': {'userId': '926F9383-7F00-48A3-9837-8E442259B715',
#    'realm': 'Fandango',
#    'displayName': 'KrisP',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '13h ago'},
#  {'rating': 'STAR_0_5',
#   'review': 'This movie is the most uninspired cash grab I have ever seen in my life. It’s sad to see such a gross waste of talent with the amazing visuals to the amazing voice actors I wish they did something original instead of the same useless boring formulaic garbage ',
#   'displayName': None,
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T20:38:48.823Z',
#   'updateDate': '2019-08-17T20:38:48.823Z',
#   'user': {'userId': '260245382',
#    'realm': 'RT',
#    'displayName': None,
#    'accountLink': '/user/id/260245382'},
#   'score': 0.5,
#   'timeFromCreation': '13h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Thought they did a great job. The family loved it! Will definitely go see it again.',
#   'displayName': 'Danielle W',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/2658894564134291/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T20:32:36.603Z',
#   'updateDate': '2019-08-17T20:32:36.603Z',
#   'user': {'userId': '978202801',
#    'realm': 'RT',
#    'displayName': 'Danielle W',
#    'accountLink': '/user/id/978202801'},
#   'score': 5,
#   'timeFromCreation': '13h ago'},
#  {'rating': 'STAR_3_5',
#   'review': 'The movie was good. There’s some songs missing. It didn’t give me the same energy as the original but again it was a good movie.',
#   'displayName': 'Shauna',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T20:19:53.807Z',
#   'updateDate': '2019-08-17T20:19:53.807Z',
#   'user': {'userId': 'CF62DA15-F66C-4321-8AA0-A4FE89E979C5',
#    'realm': 'Fandango',
#    'displayName': 'Shauna',
#    'accountLink': None},
#   'score': 3.5,
#   'timeFromCreation': '13h ago'},
#  {'rating': 'STAR_5',
#   'review': 'The new Lion King remake is phenomenal!! I personally LOVED the new Lion King. I actually like it just as much as the original if not more. I think Jon Favreau is a creative genius in his visionary take on projects. Unfortunately Disney got the Lion King right the first time, which didn’t necessitate a remake. Which is why 90% of the original had been untouched for the 2019 version. HOWEVER... I think Favreau’s brilliance will really come through if they get him to make a Lion King 2. The original is impossible to beat. But the sequels and spinoffs are much less memorable for MOST fans, yet still provide an excellent foundation for someone like Favreau to take it and really make it something special. Just like he did with Jungle Book. Jungle Book had plenty of room for creative reimagining because it’s not as widely memorable, which is where he could take liberties that he simply didn’t have with Lion King. I honestly think that the remake we got is by far the best possible job any director could’ve done with the scope of the task at hand. Excellent work and it deserves every dollar and accolade that it’s earning as we speak!! TWO THUMBS WAY UP!!!!',
#   'displayName': 'Brian',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T20:10:23.630Z',
#   'updateDate': '2019-08-17T20:10:23.630Z',
#   'user': {'userId': '4C5B2CD6-DF11-42DD-BB5B-88F5691C1BD8',
#    'realm': 'Fandango',
#    'displayName': 'Brian',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '13h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Fantastic film!! Better then the original. loved it!!!\n\nMUST SEE!!!!!🔥🔥🔥',
#   'displayName': 'Kenneth M',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T20:09:06.653Z',
#   'updateDate': '2019-08-17T20:09:06.653Z',
#   'user': {'userId': '986F0DB3-9CE0-4E42-8AA3-7F8542C9561C',
#    'realm': 'Fandango',
#    'displayName': 'Kenneth M',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '13h ago'},
#  {'rating': 'STAR_5',
#   'review': 'loved it. a little long',
#   'displayName': 'trish bolton',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T20:04:13.380Z',
#   'updateDate': '2019-08-17T20:04:13.380Z',
#   'user': {'userId': '6E99C32B-BD61-4A39-B341-1E524A2BFBCD',
#    'realm': 'Fandango',
#    'displayName': 'trish bolton',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '13h ago'},
#  {'rating': 'STAR_4',
#   'review': 'like watching national geographic',
#   'displayName': 'Carnell',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T19:18:02.914Z',
#   'updateDate': '2019-08-17T19:18:02.914Z',
#   'user': {'userId': '70C39308-2B67-4E99-BB2D-6D40BF673D05',
#    'realm': 'Fandango',
#    'displayName': 'Carnell',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '14h ago'},
#  {'rating': 'STAR_3_5',
#   'review': 'liked the movie but the original is still better',
#   'displayName': 'Facebook U',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T19:11:18.684Z',
#   'updateDate': '2019-08-17T19:11:18.684Z',
#   'user': {'userId': '7F8D1801-3BBB-4D17-B07F-E8E859E009FF',
#    'realm': 'Fandango',
#    'displayName': 'Facebook U',
#    'accountLink': None},
#   'score': 3.5,
#   'timeFromCreation': '14h ago'},
#  {'rating': 'STAR_5',
#   'review': 'done as only Disney can.',
#   'displayName': 'Linda N',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T19:11:16.397Z',
#   'updateDate': '2019-08-17T19:11:16.397Z',
#   'user': {'userId': 'DBC59A7F-00CA-4E1B-A0F8-669613E966DB',
#    'realm': 'Fandango',
#    'displayName': 'Linda N',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '14h ago'},
#  {'rating': 'STAR_4',
#   'review': 'The film setting in South Africa and the live animals makes this an even more dramatic, moving story than the original animation although a bit more scary for younger children. Portraying the eat or be eaten rules of the wild were hinted at rather than depicted- no blood in the final fight scene. The comedic warthog relieved the great loss and loneliness of Simba.',
#   'displayName': 'Connie',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T19:03:50.923Z',
#   'updateDate': '2019-08-17T19:03:50.923Z',
#   'user': {'userId': 'dcc7a523-ecd4-4f24-b64f-1ac31f6b8a98',
#    'realm': 'Fandango',
#    'displayName': 'Connie',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '14h ago'},
#  {'rating': 'STAR_5',
#   'review': 'it was true to the original & outstanding. You felt like you were there & very realistic.',
#   'displayName': 'clynn4mk',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T18:50:20.468Z',
#   'updateDate': '2019-08-17T18:50:20.468Z',
#   'user': {'userId': 'D20B5AD5-9A60-4045-A7C9-21F048C266F6',
#    'realm': 'Fandango',
#    'displayName': 'clynn4mk',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '15h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Loved the movie from beginning to end. My daughter and I saw it twice.',
#   'displayName': 'JMoerana',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T18:36:42.813Z',
#   'updateDate': '2019-08-17T18:36:42.813Z',
#   'user': {'userId': '1BBA6644-24CC-4818-8986-E278FF26E542',
#    'realm': 'Fandango',
#    'displayName': 'JMoerana',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '15h ago'},
#  {'rating': 'STAR_3',
#   'review': 'Identical to animate script without any of the magic or emotion.',
#   'displayName': 'Amber',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T18:00:53.642Z',
#   'updateDate': '2019-08-17T18:00:53.642Z',
#   'user': {'userId': 'DC10EE1F-11E4-4324-8EC3-1AF889B3C2F2',
#    'realm': 'Fandango',
#    'displayName': 'Amber',
#    'accountLink': None},
#   'score': 3,
#   'timeFromCreation': '15h ago'},
#  {'rating': 'STAR_5',
#   'review': 'It was awesome. I loved it.',
#   'displayName': 'AJ',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T17:54:33.165Z',
#   'updateDate': '2019-08-17T17:54:33.165Z',
#   'user': {'userId': 'CAEDB31E-DF1A-4F7E-95D1-95B3C53707C0',
#    'realm': 'Fandango',
#    'displayName': 'AJ',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '16h ago'},
#  {'rating': 'STAR_2_5',
#   'review': 'Modern technology and all the motion graphics are all cool and stuff but did we really need to watch the same story frame to frame? probably not. Original lion king will always have something the newer version lacks. which is emotion. ',
#   'displayName': 'Avant S',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T17:35:01.500Z',
#   'updateDate': '2019-08-17T17:35:01.500Z',
#   'user': {'userId': '972906289',
#    'realm': 'RT',
#    'displayName': 'Avant S',
#    'accountLink': '/user/id/972906289'},
#   'score': 2.5,
#   'timeFromCreation': '16h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Visually fascinating.  Of course a good story and music.',
#   'displayName': 'Patricia  B',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T17:31:55.047Z',
#   'updateDate': '2019-08-17T17:31:55.047Z',
#   'user': {'userId': '978019904',
#    'realm': 'RT',
#    'displayName': 'Patricia  B',
#    'accountLink': '/user/id/978019904'},
#   'score': 5,
#   'timeFromCreation': '16h ago'},
#  {'rating': 'STAR_1_5',
#   'review': 'I just went to the Cinemark Howard Hughes theatre near here to watch The Lion King. Children in the audience were verbally happy to be there.\n\nFrom minute one, Lion King demonstrated the awesome master combination of Disney filmmaking technics far beyond Walt Disney graphics beginnings.\n\nA scene or two later into the story, a mean aggressive hyena suddenly pops up from the shadows threatening our innocent heroes in the story. \nUnfortunately, the scene was shockingly racial. \nThe audiovisual was too overt to escape my sensibilities. \nThe hyena was black. Hyenas are generally tan or grey. Not black. You could blame it on the lighting but the hyena was black.\n\nIn fact, it appears that the mean hyena was crafted to emulate a black person. Furthermore, its voice over sounded like a black man. \n\nOf course the little children in the audience had no clue they were being brainwashed.\n\nLion King storyline attempted the proverbial Joseph Campbell mono-myth dramatic curve.  They even had the cleansing rain at the end but it was no help to improve the  distasteful bathroom humor.\nLion King failed to sustain the tit-for-tat excitement of Disney yesteryears movies. \n\nA shameless, shamefull racial movie.',
#   'displayName': 'Grandpa',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': True,
#   'createDate': '2019-08-17T17:10:16.509Z',
#   'updateDate': '2019-08-17T17:10:16.509Z',
#   'user': {'userId': 'cb7cea69-7247-43a5-a243-add6c79266d7',
#    'realm': 'Fandango',
#    'displayName': 'Grandpa',
#    'accountLink': None},
#   'score': 1.5,
#   'timeFromCreation': '16h ago'},
#  {'rating': 'STAR_4',
#   'review': "I didn't like how they changed important scenes from the original movie",
#   'displayName': 'mm',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T17:00:01.879Z',
#   'updateDate': '2019-08-17T17:00:01.879Z',
#   'user': {'userId': '71F04656-6CF7-43CD-9FD3-5E5CED5F5043',
#    'realm': 'Fandango',
#    'displayName': 'mm',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '16h ago'},
#  {'rating': 'STAR_4',
#   'review': 'Beautiful cinematography, Donald Glover and Beyonce are great!',
#   'displayName': 'Andrea H',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T16:03:13.670Z',
#   'updateDate': '2019-08-17T16:03:13.670Z',
#   'user': {'userId': '611a80bd-5bdb-4905-bb19-c5f34f341dc6',
#    'realm': 'Fandango',
#    'displayName': 'Andrea H',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '17h ago'},
#  {'rating': 'STAR_5',
#   'review': 'I didn’t go to see it..... I will!',
#   'displayName': 'Diana Renee',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T15:33:11.452Z',
#   'updateDate': '2019-08-17T15:33:11.452Z',
#   'user': {'userId': '0657A075-26F3-44BA-A264-12BAF35FE5FF',
#    'realm': 'Fandango',
#    'displayName': 'Diana Renee',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '18h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Very realistic.   Beautifully done.',
#   'displayName': 'Jane L',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T15:01:09.499Z',
#   'updateDate': '2019-08-17T15:01:09.499Z',
#   'user': {'userId': '670a9a90-1dba-49a0-bbdd-ce45fbe9348d',
#    'realm': 'Fandango',
#    'displayName': 'Jane L',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '18h ago'},
#  {'rating': 'STAR_3',
#   'review': "entertaining, but doesn't live up to its ancestor.",
#   'displayName': 'jacob',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T14:41:14.555Z',
#   'updateDate': '2019-08-17T14:41:14.555Z',
#   'user': {'userId': 'C2630603-40ED-4CA0-BA51-AA3C78AF4497',
#    'realm': 'Fandango',
#    'displayName': 'jacob',
#    'accountLink': None},
#   'score': 3,
#   'timeFromCreation': '19h ago'},
#  {'rating': 'STAR_5',
#   'review': 'The Lion King was so far fantastic movie.!',
#   'displayName': 'Venita',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T14:32:53.541Z',
#   'updateDate': '2019-08-17T14:32:53.541Z',
#   'user': {'userId': '5B67062B-8D8D-40A7-9362-BD2DA9A500A8',
#    'realm': 'Fandango',
#    'displayName': 'Venita',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '19h ago'},
#  {'rating': 'STAR_0_5',
#   'review': "The Lion King is a 2019 remake of the 1994 Disney classic The Lion King. The film was directed by Jon Favreau, and stars Donald Glover as Simba and Chiwetel Ejiofor as Scar.\n\nThe film in my opinion is a disgrace to the original film, from the emotionless character expressions to the dreadful and unfitting voice acting.\n\nThe story was basically the same as the original (nearly down to the beat), but for some reason it felt a lot less epic and not nearly as intriguing or emotional.\n\nThe voice acting I found to be stale and dry, from the lack of care in the actors voices to the bland and weary line delivery; one voice actor in particular was Shahadi Wright Joseph as (child) Simba, I found that the performance he gave was really lacking in key areas like emotion and timing.\n\nThe characters were basically just the same as the original, so I don't really have much to say here.\n\nThe animation may be extremely realistic and detailed, but what angers me most is that because of the realism the animals and characters couldn't express as much emotion as they did in the original film.\n\nThe colour scheme was also very dark and grey, which in my opinion takes away from the atmosphere and scale of the film.\n\nThe soundtrack was also a huge let down from the original film, from Beyoncé and Donald Glover's version of Can You Feel the Love Tonight (which takes place in the day) to the addition of Beyoncé's song Spirit.\n\nThe emotion and relationships in the film were also a lot less gripping, especially the relationship between Simba and Mufasa.\n\nThe film I also found to be really bland and uninteresting, but what makes it worse is that the original film was really interesting and had a very strong style to it.\n\nOver all I give it a \n1/10 - would never recommend\n\nA shallow and heartless product which should have never been made.",
#   'displayName': 'Mani P',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T14:31:39.379Z',
#   'updateDate': '2019-08-17T14:31:39.379Z',
#   'user': {'userId': '977719088',
#    'realm': 'RT',
#    'displayName': 'Mani P',
#    'accountLink': '/user/id/977719088'},
#   'score': 0.5,
#   'timeFromCreation': '19h ago'},
#  {'rating': 'STAR_3',
#   'review': 'The way the movie built was great but I think the CGI didn’t really capture the emotions of each character compare to original one and all I can see was their mouth open.There are few parts that I like but overall the cartoon is better.',
#   'displayName': 'nmh',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T14:20:03.907Z',
#   'updateDate': '2019-08-17T14:20:03.907Z',
#   'user': {'userId': 'DBBF7A07-23AE-40A4-B3E4-B3E9F51DC2B1',
#    'realm': 'Fandango',
#    'displayName': 'nmh',
#    'accountLink': None},
#   'score': 3,
#   'timeFromCreation': '19h ago'},
#  {'rating': 'STAR_4_5',
#   'review': 'Great music. Interesting use of animals. Introduction was poorly filmed, but the remainder of the film had good cinematography, Too long.',
#   'displayName': 'Hector M',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T14:19:18.545Z',
#   'updateDate': '2019-08-17T14:19:18.545Z',
#   'user': {'userId': '684CF54B-7365-4237-80FA-5CC9488A1BAE',
#    'realm': 'Fandango',
#    'displayName': 'Hector M',
#    'accountLink': None},
#   'score': 4.5,
#   'timeFromCreation': '19h ago'},
#  {'rating': 'STAR_4',
#   'review': 'I really liked this movie',
#   'displayName': 'Tasheka',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T14:07:54.229Z',
#   'updateDate': '2019-08-17T14:07:54.229Z',
#   'user': {'userId': 'D16E1AF7-CC5C-4B14-B0EC-372E067ADFF6',
#    'realm': 'Fandango',
#    'displayName': 'Tasheka',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '19h ago'},
#  {'rating': 'STAR_1',
#   'review': 'Why did I waste my money....',
#   'displayName': 'CRYSTAL T',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T13:51:20.891Z',
#   'updateDate': '2019-08-17T13:51:20.891Z',
# ...
#   'score': 5,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_4',
#   'review': 'The cinematography is unbelievable.  It looks so real.',
#   'displayName': 'Inessa',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T12:31:57.764Z',
#   'updateDate': '2019-08-09T12:31:57.764Z',
#   'user': {'userId': 'cead4320-0e7e-4f82-909e-561dde02679b',
#    'realm': 'Fandango',
#    'displayName': 'Inessa',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'I mean the movie was realistic and good that’s why i liked it but I’d recommend a lot of people to watch it',
#   'displayName': 'Jason',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T12:19:24.539Z',
#   'updateDate': '2019-08-09T12:19:24.539Z',
#   'user': {'userId': '12FE8BAF-39EE-4C96-B3CF-23A82FB7DC08',
#    'realm': 'Fandango',
#    'displayName': 'Jason',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_3',
#   'review': 'The lack of the animals facial expressions sadly stole very much from the emotion the movie wanted to transfer',
#   'displayName': 'Lara K',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T12:19:10.823Z',
#   'updateDate': '2019-08-09T12:33:50.234Z',
#   'user': {'userId': '978192229',
#    'realm': 'RT',
#    'displayName': 'Lara K',
#    'accountLink': '/user/id/978192229'},
#   'score': 3,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_2_5',
#   'review': 'Beautiful imagery but the movie felt somewhat flat and unnecessary. Also the best songs were too short.',
#   'displayName': None,
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T12:07:18.232Z',
#   'updateDate': '2019-08-09T12:07:18.232Z',
#   'user': {'userId': '906935755',
#    'realm': 'RT',
#    'displayName': None,
#    'accountLink': '/user/id/906935755'},
#   'score': 2.5,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_4',
#   'review': 'The movie was different than the cartoon. It was very realistic. The graphics were excellent.',
#   'displayName': 'Donna',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T11:58:30.576Z',
#   'updateDate': '2019-08-09T11:58:30.576Z',
#   'user': {'userId': '4812d8da-d430-40f5-8667-d9025ae805f7',
#    'realm': 'Fandango',
#    'displayName': 'Donna',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'Great to see on the big screen. Liked that it followed the classic story line.',
#   'displayName': 'Amy',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T11:50:39.819Z',
#   'updateDate': '2019-08-09T11:50:39.819Z',
#   'user': {'userId': '8a1db743-8e1d-41bd-b231-0ee8a7101a60',
#    'realm': 'Fandango',
#    'displayName': 'Amy',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_4',
#   'review': 'Very good version of the original story',
#   'displayName': 'Rodrigo',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T11:25:16.570Z',
#   'updateDate': '2019-08-09T11:25:16.570Z',
#   'user': {'userId': 'BEA0A96C-BCD4-4408-A75C-43F993478EA5',
#    'realm': 'Fandango',
#    'displayName': 'Rodrigo',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'After a few minutes, I felt like the animals were real. Great computer work. Fun movie!',
#   'displayName': 'Judy',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T11:13:05.270Z',
#   'updateDate': '2019-08-09T11:13:05.270Z',
#   'user': {'userId': 'dffb7015-0b55-4689-b1b4-af09eb18f0e2',
#    'realm': 'Fandango',
#    'displayName': 'Judy',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'Beautifully done!  Everything was so realistic.....down to the breathing  and stars and the dust kicked up by simba and nala running.   Music was wonderful.....we would see it again!',
#   'displayName': 'Susan',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T10:17:49.942Z',
#   'updateDate': '2019-08-09T10:17:49.942Z',
#   'user': {'userId': 'a97fe649-a208-4e94-b6cd-25a7ec70edae',
#    'realm': 'Fandango',
#    'displayName': 'Susan',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_1_5',
#   'review': 'Same exact movie almost frame for frame. Worse singing and hot as funny',
#   'displayName': 'Matt',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T10:13:55.879Z',
#   'updateDate': '2019-08-09T10:13:55.879Z',
#   'user': {'userId': 'cbe7c0f9-9c09-4065-91c9-5af891222667',
#    'realm': 'Fandango',
#    'displayName': 'Matt',
#    'accountLink': None},
#   'score': 1.5,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'One of the best movies Ive ever seen.  Very well done!!',
#   'displayName': 'Rebecca B',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T09:38:52.423Z',
#   'updateDate': '2019-08-09T09:38:52.423Z',
#   'user': {'userId': '55848c02-afdb-4a93-970d-3627f11f959a',
#    'realm': 'Fandango',
#    'displayName': 'Rebecca B',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_3_5',
#   'review': "It was stunningly beautiful and well done. My only complaint is that I wish they had more fun with it and branched out from the original a little. It was TOO much like the original. I mean, yeah, the original was absolutely perfect, but that's the point. If a movie is perfect, then a remake needs to be good in its own way, don't just copy it. I would've loved to see some more backstory on Scar and maybe some of his and Mufasa's childhood. That would have been amazing. Other than that, it was good!",
#   'displayName': 'Rachel A',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T09:37:08.861Z',
#   'updateDate': '2019-08-09T09:37:08.861Z',
#   'user': {'userId': '977445567',
#    'realm': 'RT',
#    'displayName': 'Rachel A',
#    'accountLink': '/user/id/977445567'},
#   'score': 3.5,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_2',
#   'review': 'expected more. cut out a lot of things.',
#   'displayName': 'CeCeMarie 💜\nCeCeMarie',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T09:28:42.162Z',
#   'updateDate': '2019-08-09T09:28:42.162Z',
#   'user': {'userId': '49E37CE8-899A-472C-A91E-D7E2F56F4FFC',
#    'realm': 'Fandango',
#    'displayName': 'CeCeMarie 💜\nCeCeMarie',
#    'accountLink': None},
#   'score': 2,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_4',
#   'review': 'I really liked it I really thought some of the scenes were done really well and the music I thought was just as good as the cartoon, like I really liked the Hakuna Matata scene and the Can you feel the love tonight I though those both sounded really well!!!!  Overall I really liked it for a Disney remake the scenes were more intense than the cartoon especially at the end when Simba was fighting Scar!!',
#   'displayName': 'Drew',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T09:13:14.863Z',
#   'updateDate': '2019-08-09T09:13:14.863Z',
#   'user': {'userId': '9cdba29f-26eb-44c5-9d1e-3b8323390a15',
#    'realm': 'Fandango',
#    'displayName': 'Drew',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_3',
#   'review': 'Technically beautiful, but emotionally flat and lacking the energy and fun of the original. My daughter loved it though, so what do I know? LOL',
#   'displayName': 'MovieNerdBen',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T08:12:39.218Z',
#   'updateDate': '2019-08-09T08:12:39.218Z',
#   'user': {'userId': '98A92FDA-4AAA-45ED-BB92-7477097106C1',
#    'realm': 'Fandango',
#    'displayName': 'MovieNerdBen',
#    'accountLink': None},
#   'score': 3,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'I enjoyed the whole movie. It took me back to 1994, when Lion King became my favorite movie. Although it had different scripts (some added, some removed), the remake was awesome.',
#   'displayName': 'Lissette T',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T08:06:55.694Z',
#   'updateDate': '2019-08-09T08:06:55.694Z',
#   'user': {'userId': '03ABAEDF-8D6A-47E1-B83A-79F2288327A8',
#    'realm': 'Fandango',
#    'displayName': 'Lissette T',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'It was ahhhhhmazing!!!! There were times I wanted to take my phone out to take a picture it seemed so real. Absolutely loved it!!!',
#   'displayName': 'Lora',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T05:55:07.604Z',
#   'updateDate': '2019-08-09T05:55:07.604Z',
#   'user': {'userId': '7246C5FC-F9D7-4C93-80ED-19A81A9E253F',
#    'realm': 'Fandango',
#    'displayName': 'Lora',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'Loved the movie!! It was great!!',
#   'displayName': 'Rachel J',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T05:11:38.076Z',
#   'updateDate': '2019-08-09T05:11:38.076Z',
#   'user': {'userId': 'E6FCDE5C-D042-424D-866F-FE86FE7FBA9C',
#    'realm': 'Fandango',
#    'displayName': 'Rachel J',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_4',
#   'review': 'I thought it was a very cute movie for kids with a good message. My 7 and 8 year old granddaughters just loved it.\n',
#   'displayName': 'terri w',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T05:03:25.718Z',
#   'updateDate': '2019-08-09T05:03:25.726Z',
#   'user': {'userId': '978191959',
#    'realm': 'RT',
#    'displayName': 'terri w',
#    'accountLink': '/user/id/978191959'},
#   'score': 4,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_2',
#   'review': 'It started out with some awesome scenery and shots of African wildlife.  However, the storytelling was labored and too predictable.  When you have an epic tale like Lion King, you cant just let it play out without an added point of interest either in the storyline or the characters.   I found the characters rather bland. Simba is not really resolving his feelings of guilt and the Hakuna Matata song does little to get the message across that a positive outlook can change anything.  Scar is given more screen time than necessary and the final battle between Simba and Scar goes on for far too long.  In fact long enough for my 12 year old grandson to start fidgeting and checking his watch to see when the end would come.  Nala is forgettable and so are most of the other characters with perhaps the exception of Zazu, the dodo bird.  The music left me cold and did nothing to bring back memories of the unforgettable live musical I so loved and enjoyed.',
#   'displayName': 'Hanny',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T05:02:44.130Z',
#   'updateDate': '2019-08-11T03:50:30.480Z',
#   'user': {'userId': 'ab893df6-7875-4786-8543-b5b57306fb38',
#    'realm': 'Fandango',
#    'displayName': 'Hanny',
#    'accountLink': None},
#   'score': 2,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_4',
#   'review': 'I took my 8 year old grandson. We both enjoyed the movie. I had read that it wasnt very good because the animals did not display emotion. This is true, but it did not stop us from enjoying the story.',
#   'displayName': 'Diane O',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T05:02:28.837Z',
#   'updateDate': '2019-08-09T05:02:28.837Z',
#   'user': {'userId': 'b49fd18e-d707-4554-9f51-0e6fecf2be96',
#    'realm': 'Fandango',
#    'displayName': 'Diane O',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_3',
#   'review': 'The animated version is still number one.  All the songs sounded rushed.  Very few songs were equal to the animated version.',
#   'displayName': 'nrc',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T04:49:25.530Z',
#   'updateDate': '2019-08-09T04:49:25.530Z',
#   'user': {'userId': 'F3D2D151-E490-4ED6-AEE2-87638DBDF8DF',
#    'realm': 'Fandango',
#    'displayName': 'nrc',
#    'accountLink': None},
#   'score': 3,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'Wonderful movie. I love this movie with the real animals.',
#   'displayName': 'Pat',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T04:39:35.903Z',
#   'updateDate': '2019-08-09T04:39:35.903Z',
#   'user': {'userId': '88e4286e-228e-47dd-8f65-97bff464b157',
#    'realm': 'Fandango',
#    'displayName': 'Pat',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_3',
#   'review': 'My 3 stars is for the special effects alone. It was cool to see one of my favorite Disney movies come to life. I just hate they didn’t make anything new or fresh about it. The songs were worse, the punchlines did not land and it felt lazy. Really wish they would have added new songs, new story lines and better singing. ',
#   'displayName': None,
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T04:35:27.259Z',
#   'updateDate': '2019-08-09T04:35:49.095Z',
#   'user': {'userId': '937722524',
#    'realm': 'RT',
#    'displayName': None,
#    'accountLink': '/user/id/937722524'},
#   'score': 3,
#   'timeFromCreation': 'Aug 09, 2019'},
#  {'rating': 'STAR_2',
#   'review': 'By trying to be realistic the movie loses its charm and impact',
#   'displayName': 'JAde Amber B',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T04:34:30.079Z',
#   'updateDate': '2019-08-09T04:34:30.079Z',
#   'user': {'userId': '904345406',
#    'realm': 'RT',
#    'displayName': 'JAde Amber B',
#    'accountLink': '/user/id/904345406'},
#   'score': 2,
#   'timeFromCreation': 'Aug 09, 2019'},
#  ...]

# %%
#We can see from above json file that the user information is captured in seperate dictionary within the review dictionary.
#So, pull the user information from user dictionary in key:value pair seperately.and then delete the attribute to avoid repetition.


for value in all_reviews:
    value['userId'] = value['user']['userId']
    value['userRealm'] = value['user']['realm']
    value['userDisplayName'] = value['user']['displayName']
    value['userAccountLink'] = value['user']['accountLink']
    del value['user'];

# %%
#Check the length of the all_review.

len(all_reviews)
# Out:
# 3000

# %%
#As We have seperated the user attribute, lets check the content now.

all_reviews
# Out:
# [{'rating': 'STAR_5',
#   'review': 'I liked most that the animation made the animals look so real',
#   'displayName': 'Joanne H',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T08:54:30.664Z',
#   'updateDate': '2019-08-18T08:54:30.890Z',
#   'score': 5,
#   'timeFromCreation': '31m ago',
#   'userId': '2c73ed20-5b9f-41b3-a4fd-8dd3ff8bb20a',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Joanne H',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'Amazing! So realistic and incredible music',
#   'displayName': 'Frankie C',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/594379764/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T08:03:49.380Z',
#   'updateDate': '2019-08-18T08:03:49.380Z',
#   'score': 5,
#   'timeFromCreation': '1h ago',
#   'userId': '871398953',
#   'userRealm': 'RT',
#   'userDisplayName': 'Frankie C',
#   'userAccountLink': '/user/id/871398953'},
#  {'rating': 'STAR_5',
#   'review': 'Classic. Good remake. Loved it. Glover was outstanding',
#   'displayName': 'jaycee',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T07:13:32.422Z',
#   'updateDate': '2019-08-18T07:13:32.422Z',
#   'score': 5,
#   'timeFromCreation': '2h ago',
#   'userId': 'DD2453B0-37CE-4B47-A099-D15378FC310E',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'jaycee',
#   'userAccountLink': None},
#  {'rating': 'STAR_2',
#   'review': 'Nice animation/CGI but completely lacking the "Disney" style humour and wonder of the original.  Undue concentration on violence scared the kiddies.  The real question is "Why?"',
#   'displayName': 'Peter A',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/100000479373060/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T07:06:08.698Z',
#   'updateDate': '2019-08-18T07:06:46.610Z',
#   'score': 2,
#   'timeFromCreation': '2h ago',
#   'userId': '906750266',
#   'userRealm': 'RT',
#   'userDisplayName': 'Peter A',
#   'userAccountLink': '/user/id/906750266'},
#  {'rating': 'STAR_4',
#   'review': 'Good but go mainly for the sentimental value',
#   'displayName': 'Kevin M',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T06:38:46.892Z',
#   'updateDate': '2019-08-18T06:38:46.892Z',
#   'score': 4,
#   'timeFromCreation': '3h ago',
#   'userId': '21FE7D93-351C-43B5-833D-B1DB11F3FD6A',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Kevin M',
#   'userAccountLink': None},
#  {'rating': 'STAR_4',
#   'review': 'The animation was really good',
#   'displayName': 'Angelwolf',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T05:34:19.360Z',
#   'updateDate': '2019-08-18T05:34:19.360Z',
#   'score': 4,
#   'timeFromCreation': '4h ago',
#   'userId': 'E62CDAD2-329A-4924-8455-35249C3BCC4D',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Angelwolf',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'i thought it was awesone. i really like the originalaty of the animals.really enjoyed it .i would see it again.  they nailed it .cant wait till dvd comes out .very much worth it',
#   'displayName': 'sheril',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T05:22:03.783Z',
#   'updateDate': '2019-08-18T05:22:03.783Z',
#   'score': 5,
#   'timeFromCreation': '4h ago',
#   'userId': '8229f609-93a7-4c8e-8ec7-37b18fa65679',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'sheril',
#   'userAccountLink': None},
#  {'rating': 'STAR_3',
#   'review': 'I think that they should’ve brought back more of the original voice actors, This movie is so iconic and So important to so many people... I don’t think they did it any justice the way it is.  If they had created an entirely new story with the kind of computer generated animals that were in the lion King they would have had an amazing movie but, the way it is now it was kind of disappointing',
#   'displayName': 'Maggie L',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T05:14:42.958Z',
#   'updateDate': '2019-08-18T05:14:42.958Z',
#   'score': 3,
#   'timeFromCreation': '4h ago',
#   'userId': '8B9ED608-C9C6-4EAF-82A3-1DF9FFFD0EA4',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Maggie L',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'Great, absolutely great!  The animation was great, the story line spot on and Beyoncé delivered.  A little more violence than the animated version but that was expected.  Overall - loved it.',
#   'displayName': 'Bryan A',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T04:58:59.214Z',
#   'updateDate': '2019-08-18T04:58:59.214Z',
#   'score': 5,
#   'timeFromCreation': '4h ago',
#   'userId': 'C792B3A4-EC33-48C2-A911-A2AAB946B94F',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Bryan A',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'It was just like the first one. Very good animation. Very cute movie',
#   'displayName': 'Bethany',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T04:51:44.361Z',
#   'updateDate': '2019-08-18T04:51:44.361Z',
#   'score': 5,
#   'timeFromCreation': '5h ago',
#   'userId': '45c8dfaa-e20f-44df-8f01-445c0f055e42',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Bethany',
#   'userAccountLink': None},
#  {'rating': 'STAR_3',
#   'review': "Didn't make me feel anything unlike the original.",
#   'displayName': 'Alexander G',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T04:35:16.243Z',
#   'updateDate': '2019-08-18T04:35:16.243Z',
#   'score': 3,
#   'timeFromCreation': '5h ago',
#   'userId': '978203293',
#   'userRealm': 'RT',
#   'userDisplayName': 'Alexander G',
#   'userAccountLink': '/user/id/978203293'},
#  {'rating': 'STAR_5',
#   'review': 'Well done! A great way to redo a classic. It felt part National Geographic, part Pixar. Loved watching all of the animal species in their habitat.',
#   'displayName': 'Lori',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T04:10:11.153Z',
#   'updateDate': '2019-08-18T04:10:11.153Z',
#   'score': 5,
#   'timeFromCreation': '5h ago',
#   'userId': '8ce21b61-d2b1-453e-ab78-fe0ba06088d5',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Lori',
#   'userAccountLink': None},
#  {'rating': 'STAR_4',
#   'review': 'Good movie.  Just that the original animated was better, in my humble opinion.',
#   'displayName': 'Tim stoeckle',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T03:39:22.555Z',
#   'updateDate': '2019-08-18T03:39:22.555Z',
#   'score': 4,
#   'timeFromCreation': '6h ago',
#   'userId': '4e4abb87-64d4-4f65-8673-8e0b9b612c1b',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Tim stoeckle',
#   'userAccountLink': None},
#  {'rating': 'STAR_3',
#   'review': 'I didn’t like Beyoncé being nala. Bad acting. I didn’t like that they kept some things out. I didn’t like some of the stuff that they added was unnecessary. It’s a very good classic no need to try to fix or change something that is very nostalgic to childhood memories. So for me it was more of a 2.5 rating.',
#   'displayName': 'Sheena',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T03:28:50.700Z',
#   'updateDate': '2019-08-18T03:28:50.700Z',
#   'score': 3,
#   'timeFromCreation': '6h ago',
#   'userId': 'C211508E-B600-44E0-A289-C43EEDF30831',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Sheena',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': "Such a beautiful story. We've loved the animated version for years, but this was a step up. The animals were all so beautiful, except the hyenas, which were really scary!",
#   'displayName': 'Marsha C',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T03:25:45.583Z',
#   'updateDate': '2019-08-18T03:25:45.583Z',
#   'score': 5,
#   'timeFromCreation': '6h ago',
#   'userId': '9c220502-046b-4b98-a0d1-ad271ed611f8',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Marsha C',
#   'userAccountLink': None},
#  {'rating': 'STAR_4',
#   'review': 'great Flick, Kids had some good Laughs,.',
#   'displayName': 'Rigo',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T03:25:08.042Z',
#   'updateDate': '2019-08-18T03:25:08.042Z',
#   'score': 4,
#   'timeFromCreation': '6h ago',
#   'userId': 'E5B8CCF8-F6B5-4ACD-B1AC-D7736129DB0C',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Rigo',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'It was great!! We loved it.',
#   'displayName': 'Eckj',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T03:15:54.657Z',
#   'updateDate': '2019-08-18T03:15:54.657Z',
#   'score': 5,
#   'timeFromCreation': '6h ago',
#   'userId': '75b78309-78b8-4670-8cef-26693359f0ab',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Eckj',
#   'userAccountLink': None},
#  {'rating': 'STAR_4_5',
#   'review': 'It’s The Lion King! This movie is absolutely gorgeous. Every little detail was thought of and shown in this movie. From the soundtrack to the story it’ll take you right back to the first time you saw it when you were a kid.',
#   'displayName': 'Chandler',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T03:15:48.253Z',
#   'updateDate': '2019-08-18T03:15:48.253Z',
#   'score': 4.5,
#   'timeFromCreation': '6h ago',
#   'userId': 'D6FAE8CA-89D2-49FD-8DFE-90ECCD197DF6',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Chandler',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'I truly enjoyed this movie from the story to the music. Had such a great cast',
#   'displayName': 'Jeffrey B',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T03:08:09.223Z',
#   'updateDate': '2019-08-18T03:08:09.223Z',
#   'score': 5,
#   'timeFromCreation': '6h ago',
#   'userId': '978203215',
#   'userRealm': 'RT',
#   'userDisplayName': 'Jeffrey B',
#   'userAccountLink': '/user/id/978203215'},
#  {'rating': 'STAR_5',
#   'review': 'All of the animals were so life-like and real!  I dont know how they do that!  WONDERFUL!  Loved it!',
#   'displayName': 'Linda Lea',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T02:30:52.219Z',
#   'updateDate': '2019-08-18T02:30:52.219Z',
#   'score': 5,
#   'timeFromCreation': '7h ago',
#   'userId': '820a7d8b-6d22-447a-9ed9-02dc1437db87',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Linda Lea',
#   'userAccountLink': None},
#  {'rating': 'STAR_4',
#   'review': 'Very good movie a little violent for young kids maybe',
#   'displayName': 'Tim T',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T02:29:04.887Z',
#   'updateDate': '2019-08-18T02:29:04.887Z',
#   'score': 4,
#   'timeFromCreation': '7h ago',
#   'userId': '7b25d789-e4e6-4eb4-9f75-500c240b5706',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Tim T',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'awesome!!! a must see',
#   'displayName': 'ch',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T02:14:40.116Z',
#   'updateDate': '2019-08-18T02:14:40.116Z',
#   'score': 5,
#   'timeFromCreation': '7h ago',
#   'userId': 'D91F2EBC-B1EF-4D59-BEF2-D59000B603D0',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'ch',
#   'userAccountLink': None},
#  {'rating': 'STAR_0_5',
#   'review': 'Animation was good. Nearly every line was the exact same as the old movie though so its very boring. Besides the way the movie looks it is the exact same. Dont really understand why they remade this one. At least the Aladdin remake had some changes to the story line and new songs to keep it fresh and entertaining',
#   'displayName': 'J',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T02:07:24.616Z',
#   'updateDate': '2019-08-18T02:07:32.852Z',
#   'score': 0.5,
#   'timeFromCreation': '7h ago',
#   'userId': '2406414a-397f-4d7a-affc-b0a912d2fdab',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'J',
#   'userAccountLink': None},
#  {'rating': 'STAR_4_5',
#   'review': 'Not the original, but just as special.',
#   'displayName': None,
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T01:43:16.296Z',
#   'updateDate': '2019-08-18T01:43:16.296Z',
#   'score': 4.5,
#   'timeFromCreation': '8h ago',
#   'userId': '260314256',
#   'userRealm': 'RT',
#   'userDisplayName': None,
#   'userAccountLink': '/user/id/260314256'},
#  {'rating': 'STAR_3',
#   'review': "the hype didn't meet expectations",
#   'displayName': 'sheri w',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T01:40:56.927Z',
#   'updateDate': '2019-08-18T01:40:56.927Z',
#   'score': 3,
#   'timeFromCreation': '8h ago',
#   'userId': 'D43132C3-78D5-48D7-9A3A-F66A5038E557',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'sheri w',
#   'userAccountLink': None},
#  {'rating': 'STAR_4',
#   'review': 'While rated PG, it is most appropriate for fourth or fifth graders & up.',
#   'displayName': 'Kenneth P.',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T01:29:38.529Z',
#   'updateDate': '2019-08-18T01:29:38.529Z',
#   'score': 4,
#   'timeFromCreation': '8h ago',
#   'userId': '1772b651-3b2d-418e-998d-cd7e588c3b2c',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Kenneth P.',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'Very good adaptation of the original cartoon with realistic looking animation.',
#   'displayName': 'Salsamanp',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T01:28:25.450Z',
#   'updateDate': '2019-08-18T01:28:25.450Z',
#   'score': 5,
#   'timeFromCreation': '8h ago',
#   'userId': '219cb505-1e94-4299-9511-dafae418922a',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Salsamanp',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'Wonderful and pretty close to the original!',
#   'displayName': 'Jennifer',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T01:04:16.101Z',
#   'updateDate': '2019-08-18T01:04:16.101Z',
#   'score': 5,
#   'timeFromCreation': '8h ago',
#   'userId': '9D2E9337-C3D2-4A18-8976-59C9705C0948',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Jennifer',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'Loved it. I loved the original cartoon so I have it a shot and tell on love.',
#   'displayName': 'SWalt',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T00:59:46.371Z',
#   'updateDate': '2019-08-18T00:59:46.371Z',
#   'score': 5,
#   'timeFromCreation': '8h ago',
#   'userId': '20929b8f-e35e-469d-83a8-224b257e5c13',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'SWalt',
#   'userAccountLink': None},
#  {'rating': 'STAR_4',
#   'review': 'Same history, more realist. Good work. ',
#   'displayName': 'Juan S',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T00:57:22.168Z',
#   'updateDate': '2019-08-18T00:57:22.165Z',
#   'score': 4,
#   'timeFromCreation': '8h ago',
#   'userId': '978203088',
#   'userRealm': 'RT',
#   'userDisplayName': 'Juan S',
#   'userAccountLink': '/user/id/978203088'},
#  {'rating': 'STAR_5',
#   'review': 'This story will never grow old....just a fresh perspective on wonderful!',
#   'displayName': 'Paula R',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T00:18:38.119Z',
#   'updateDate': '2019-08-18T00:18:38.119Z',
#   'score': 5,
#   'timeFromCreation': '9h ago',
#   'userId': 'c06d43ca-18b3-42f7-a9bf-7e5cfb7fc39d',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Paula R',
#   'userAccountLink': None},
#  {'rating': 'STAR_2',
#   'review': 'I fell asleep several times.  Animated movie was so much better.',
#   'displayName': 'scouting6',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T00:14:59.136Z',
#   'updateDate': '2019-08-18T00:14:59.136Z',
#   'score': 2,
#   'timeFromCreation': '9h ago',
#   'userId': '82FCCD42-66C4-41E7-96F7-DE3B46764B51',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'scouting6',
#   'userAccountLink': None},
#  {'rating': 'STAR_2_5',
#   'review': "VERY BEAUTIFUL. The CGI looked genuinely amazing but that's all I really have to say. The animated one was so much better. At least they brought back James Earl Jones. However SETH ROGAN should NOT have been PUMBA. I now will always picture Pumba as a stoner",
#   'displayName': 'David G',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T00:12:48.842Z',
#   'updateDate': '2019-08-18T00:12:48.842Z',
#   'score': 2.5,
#   'timeFromCreation': '9h ago',
#   'userId': '978171705',
#   'userRealm': 'RT',
#   'userDisplayName': 'David G',
#   'userAccountLink': '/user/id/978171705'},
#  {'rating': 'STAR_5',
#   'review': 'It was wonderful!! My family loved it! There is nothing i would change. It was perfect!!😊',
#   'displayName': 'Michelle Salazar',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-18T00:06:43.886Z',
#   'updateDate': '2019-08-18T00:06:43.886Z',
#   'score': 5,
#   'timeFromCreation': '9h ago',
#   'userId': 'F73BC87D-F6D2-4F9D-A1AD-A4324462D0EC',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Michelle Salazar',
#   'userAccountLink': None},
#  {'rating': 'STAR_4',
#   'review': 'Very entertaining. Seth Rogan as Pumba was excellent. Please tell me how on Earth you recite “Be Prepared”?! We got jilted out of that. Also, star off because remakes involving animals don’t go over as well as humans. Aladdin allowed you to better immerse yourself, since there were humans you could connect with. I don’t think anything was gained by remaking Lion King.',
#   'displayName': 'Cet',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T23:47:09.266Z',
#   'updateDate': '2019-08-17T23:47:09.266Z',
#   'score': 4,
#   'timeFromCreation': '10h ago',
#   'userId': 'B68B17A0-1F10-4C61-9D29-A3EE48822C4B',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Cet',
#   'userAccountLink': None},
#  {'rating': 'STAR_4_5',
#   'review': 'Greatest adaptation!!!',
#   'displayName': 'Charles Ward',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T23:37:13.441Z',
#   'updateDate': '2019-08-17T23:37:13.441Z',
#   'score': 4.5,
#   'timeFromCreation': '10h ago',
#   'userId': '8A06AC36-221D-426F-A117-45BEAD96C09E',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Charles Ward',
#   'userAccountLink': None},
#  {'rating': 'STAR_3_5',
#   'review': "I don't know what to feel about this movie.\nI was waiting to see it since it was announced that it was going out, I saw the trailer and the emotion was great but at the moment of seeing it the feeling was different. I felt that it was not what I expected.\nI will not deny that the effects and the music were incredible, but I do not know why but the plot did not convince me. I felt that I had seen another movie and not THE LION KING.\nIt would have been nice if this movie would have looked a little closer to the original. I think that I would have enjoyed it more.\nI can say that I liked it but I did not enjoy it at all.",
#   'displayName': 'Claudia C',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T23:21:09.548Z',
#   'updateDate': '2019-08-17T23:21:09.548Z',
#   'score': 3.5,
#   'timeFromCreation': '10h ago',
#   'userId': '978202971',
#   'userRealm': 'RT',
#   'userDisplayName': 'Claudia C',
#   'userAccountLink': '/user/id/978202971'},
#  {'rating': 'STAR_4_5',
#   'review': "I really liked this remake of the Disney Classic.  I didn't like how the movie changed certain iconic aspects of the original. Overall though, the movie was basically the exact same as the original and also includes a few extra scenes that help to tell the story.  I would definitely go see this before it leaves theaters!",
#   'displayName': 'Google',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T23:06:14.086Z',
#   'updateDate': '2019-08-17T23:06:14.086Z',
#   'score': 4.5,
#   'timeFromCreation': '10h ago',
#   'userId': '7af5a466-5e13-4dea-84e6-3d28403f02d2',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Google',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'Great performances and altogether recreation',
#   'displayName': 'Shamontae',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T22:58:31.474Z',
#   'updateDate': '2019-08-17T22:58:31.474Z',
#   'score': 5,
#   'timeFromCreation': '10h ago',
#   'userId': '3cca24e6-e906-4d4e-bff5-641f546314c9',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Shamontae',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'Great movie for the kids.',
#   'displayName': 'Angel',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T22:52:20.114Z',
#   'updateDate': '2019-08-17T22:52:20.114Z',
#   'score': 5,
#   'timeFromCreation': '11h ago',
#   'userId': 'C1CEC4B4-575E-4030-B4C8-B77CECFF19D3',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Angel',
#   'userAccountLink': None},
#  {'rating': 'STAR_4_5',
#   'review': 'Fulfilled my nostalgia',
#   'displayName': 'Ellena',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T22:42:15.647Z',
#   'updateDate': '2019-08-17T22:42:15.647Z',
#   'score': 4.5,
#   'timeFromCreation': '11h ago',
#   'userId': '091629A5-E372-4164-BDC3-16BEB6D1CF2F',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Ellena',
#   'userAccountLink': None},
#  {'rating': 'STAR_2',
#   'review': 'Hated that it was different that original',
#   'displayName': 'Heidi L',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T22:32:28.679Z',
#   'updateDate': '2019-08-17T22:32:28.679Z',
#   'score': 2,
#   'timeFromCreation': '11h ago',
#   'userId': '9D7FC189-CD94-404D-9F2C-F1A42FF4AF41',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Heidi L',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'Loved the special affects',
#   'displayName': 'Lenora',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T22:18:43.032Z',
#   'updateDate': '2019-08-17T22:18:43.032Z',
#   'score': 5,
#   'timeFromCreation': '11h ago',
#   'userId': '0EC70ECD-F63E-4ACD-ABF7-C3D983B56AA6',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Lenora',
#   'userAccountLink': None},
#  {'rating': 'STAR_3',
#   'review': 'Not much humor. Not even close to as good as the original. I had high hopes after watching the Jungle Book remake by this director. Just seemed uninspired. It had pretty good CGI however.',
#   'displayName': 'Ted',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T22:04:48.038Z',
#   'updateDate': '2019-08-17T22:04:48.038Z',
#   'score': 3,
#   'timeFromCreation': '11h ago',
#   'userId': 'C7AA7076-7B30-4882-859E-9BBCF727D49D',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Ted',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'It was amazing. Best Disney remake!',
#   'displayName': 'Alyssa',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T21:49:44.181Z',
#   'updateDate': '2019-08-17T21:49:44.181Z',
#   'score': 5,
#   'timeFromCreation': '12h ago',
#   'userId': '93717EC0-2BBB-4D7E-B379-1317E137BA80',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Alyssa',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'great movie just like the original',
#   'displayName': 'cindy',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T21:18:39.378Z',
#   'updateDate': '2019-08-17T21:18:39.378Z',
#   'score': 5,
#   'timeFromCreation': '12h ago',
#   'userId': 'D641A434-A130-484A-BEC8-FD95FFE6CA62',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'cindy',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'of all the new Disney remakes, this was by far my favorite one!',
#   'displayName': 'Madeleine',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T21:17:37.894Z',
#   'updateDate': '2019-08-17T21:17:37.894Z',
#   'score': 5,
#   'timeFromCreation': '12h ago',
#   'userId': 'D47EE08C-77C9-46D5-94E9-7B5E765FFA6E',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Madeleine',
#   'userAccountLink': None},
#  {'rating': 'STAR_3',
#   'review': 'It was fine. Basically a shot for shot remake of the original without the fun and emotion. This won’t be replacing the animated version in our viewing list.',
#   'displayName': 'nora',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T21:13:25.779Z',
#   'updateDate': '2019-08-17T21:13:25.779Z',
#   'score': 3,
#   'timeFromCreation': '12h ago',
#   'userId': 'A70EC39F-D8BB-4249-9635-4AF4DAAC0C52',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'nora',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': "Go and see it. It's worth it",
#   'displayName': 'KrisP',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T20:52:39.008Z',
#   'updateDate': '2019-08-17T20:52:39.008Z',
#   'score': 5,
#   'timeFromCreation': '13h ago',
#   'userId': '926F9383-7F00-48A3-9837-8E442259B715',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'KrisP',
#   'userAccountLink': None},
#  {'rating': 'STAR_0_5',
#   'review': 'This movie is the most uninspired cash grab I have ever seen in my life. It’s sad to see such a gross waste of talent with the amazing visuals to the amazing voice actors I wish they did something original instead of the same useless boring formulaic garbage ',
#   'displayName': None,
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T20:38:48.823Z',
#   'updateDate': '2019-08-17T20:38:48.823Z',
#   'score': 0.5,
#   'timeFromCreation': '13h ago',
#   'userId': '260245382',
#   'userRealm': 'RT',
#   'userDisplayName': None,
#   'userAccountLink': '/user/id/260245382'},
#  {'rating': 'STAR_5',
#   'review': 'Thought they did a great job. The family loved it! Will definitely go see it again.',
#   'displayName': 'Danielle W',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/2658894564134291/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T20:32:36.603Z',
#   'updateDate': '2019-08-17T20:32:36.603Z',
#   'score': 5,
#   'timeFromCreation': '13h ago',
#   'userId': '978202801',
#   'userRealm': 'RT',
#   'userDisplayName': 'Danielle W',
#   'userAccountLink': '/user/id/978202801'},
#  {'rating': 'STAR_3_5',
#   'review': 'The movie was good. There’s some songs missing. It didn’t give me the same energy as the original but again it was a good movie.',
#   'displayName': 'Shauna',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T20:19:53.807Z',
#   'updateDate': '2019-08-17T20:19:53.807Z',
#   'score': 3.5,
#   'timeFromCreation': '13h ago',
#   'userId': 'CF62DA15-F66C-4321-8AA0-A4FE89E979C5',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Shauna',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'The new Lion King remake is phenomenal!! I personally LOVED the new Lion King. I actually like it just as much as the original if not more. I think Jon Favreau is a creative genius in his visionary take on projects. Unfortunately Disney got the Lion King right the first time, which didn’t necessitate a remake. Which is why 90% of the original had been untouched for the 2019 version. HOWEVER... I think Favreau’s brilliance will really come through if they get him to make a Lion King 2. The original is impossible to beat. But the sequels and spinoffs are much less memorable for MOST fans, yet still provide an excellent foundation for someone like Favreau to take it and really make it something special. Just like he did with Jungle Book. Jungle Book had plenty of room for creative reimagining because it’s not as widely memorable, which is where he could take liberties that he simply didn’t have with Lion King. I honestly think that the remake we got is by far the best possible job any director could’ve done with the scope of the task at hand. Excellent work and it deserves every dollar and accolade that it’s earning as we speak!! TWO THUMBS WAY UP!!!!',
#   'displayName': 'Brian',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T20:10:23.630Z',
#   'updateDate': '2019-08-17T20:10:23.630Z',
#   'score': 5,
#   'timeFromCreation': '13h ago',
#   'userId': '4C5B2CD6-DF11-42DD-BB5B-88F5691C1BD8',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Brian',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'Fantastic film!! Better then the original. loved it!!!\n\nMUST SEE!!!!!🔥🔥🔥',
#   'displayName': 'Kenneth M',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T20:09:06.653Z',
#   'updateDate': '2019-08-17T20:09:06.653Z',
#   'score': 5,
#   'timeFromCreation': '13h ago',
#   'userId': '986F0DB3-9CE0-4E42-8AA3-7F8542C9561C',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Kenneth M',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'loved it. a little long',
#   'displayName': 'trish bolton',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T20:04:13.380Z',
#   'updateDate': '2019-08-17T20:04:13.380Z',
#   'score': 5,
#   'timeFromCreation': '13h ago',
#   'userId': '6E99C32B-BD61-4A39-B341-1E524A2BFBCD',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'trish bolton',
#   'userAccountLink': None},
#  {'rating': 'STAR_4',
#   'review': 'like watching national geographic',
#   'displayName': 'Carnell',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T19:18:02.914Z',
#   'updateDate': '2019-08-17T19:18:02.914Z',
#   'score': 4,
#   'timeFromCreation': '14h ago',
#   'userId': '70C39308-2B67-4E99-BB2D-6D40BF673D05',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Carnell',
#   'userAccountLink': None},
#  {'rating': 'STAR_3_5',
#   'review': 'liked the movie but the original is still better',
#   'displayName': 'Facebook U',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T19:11:18.684Z',
#   'updateDate': '2019-08-17T19:11:18.684Z',
#   'score': 3.5,
#   'timeFromCreation': '14h ago',
#   'userId': '7F8D1801-3BBB-4D17-B07F-E8E859E009FF',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Facebook U',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'done as only Disney can.',
#   'displayName': 'Linda N',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T19:11:16.397Z',
#   'updateDate': '2019-08-17T19:11:16.397Z',
#   'score': 5,
#   'timeFromCreation': '14h ago',
#   'userId': 'DBC59A7F-00CA-4E1B-A0F8-669613E966DB',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Linda N',
#   'userAccountLink': None},
#  {'rating': 'STAR_4',
#   'review': 'The film setting in South Africa and the live animals makes this an even more dramatic, moving story than the original animation although a bit more scary for younger children. Portraying the eat or be eaten rules of the wild were hinted at rather than depicted- no blood in the final fight scene. The comedic warthog relieved the great loss and loneliness of Simba.',
#   'displayName': 'Connie',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T19:03:50.923Z',
#   'updateDate': '2019-08-17T19:03:50.923Z',
#   'score': 4,
#   'timeFromCreation': '14h ago',
#   'userId': 'dcc7a523-ecd4-4f24-b64f-1ac31f6b8a98',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Connie',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'it was true to the original & outstanding. You felt like you were there & very realistic.',
#   'displayName': 'clynn4mk',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T18:50:20.468Z',
#   'updateDate': '2019-08-17T18:50:20.468Z',
#   'score': 5,
#   'timeFromCreation': '15h ago',
#   'userId': 'D20B5AD5-9A60-4045-A7C9-21F048C266F6',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'clynn4mk',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'Loved the movie from beginning to end. My daughter and I saw it twice.',
#   'displayName': 'JMoerana',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T18:36:42.813Z',
#   'updateDate': '2019-08-17T18:36:42.813Z',
#   'score': 5,
#   'timeFromCreation': '15h ago',
#   'userId': '1BBA6644-24CC-4818-8986-E278FF26E542',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'JMoerana',
#   'userAccountLink': None},
#  {'rating': 'STAR_3',
#   'review': 'Identical to animate script without any of the magic or emotion.',
#   'displayName': 'Amber',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T18:00:53.642Z',
#   'updateDate': '2019-08-17T18:00:53.642Z',
#   'score': 3,
#   'timeFromCreation': '15h ago',
#   'userId': 'DC10EE1F-11E4-4324-8EC3-1AF889B3C2F2',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Amber',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'It was awesome. I loved it.',
#   'displayName': 'AJ',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T17:54:33.165Z',
#   'updateDate': '2019-08-17T17:54:33.165Z',
#   'score': 5,
#   'timeFromCreation': '16h ago',
#   'userId': 'CAEDB31E-DF1A-4F7E-95D1-95B3C53707C0',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'AJ',
#   'userAccountLink': None},
#  {'rating': 'STAR_2_5',
#   'review': 'Modern technology and all the motion graphics are all cool and stuff but did we really need to watch the same story frame to frame? probably not. Original lion king will always have something the newer version lacks. which is emotion. ',
#   'displayName': 'Avant S',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T17:35:01.500Z',
#   'updateDate': '2019-08-17T17:35:01.500Z',
#   'score': 2.5,
#   'timeFromCreation': '16h ago',
#   'userId': '972906289',
#   'userRealm': 'RT',
#   'userDisplayName': 'Avant S',
#   'userAccountLink': '/user/id/972906289'},
#  {'rating': 'STAR_5',
#   'review': 'Visually fascinating.  Of course a good story and music.',
#   'displayName': 'Patricia  B',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T17:31:55.047Z',
#   'updateDate': '2019-08-17T17:31:55.047Z',
#   'score': 5,
#   'timeFromCreation': '16h ago',
#   'userId': '978019904',
#   'userRealm': 'RT',
#   'userDisplayName': 'Patricia  B',
#   'userAccountLink': '/user/id/978019904'},
#  {'rating': 'STAR_1_5',
#   'review': 'I just went to the Cinemark Howard Hughes theatre near here to watch The Lion King. Children in the audience were verbally happy to be there.\n\nFrom minute one, Lion King demonstrated the awesome master combination of Disney filmmaking technics far beyond Walt Disney graphics beginnings.\n\nA scene or two later into the story, a mean aggressive hyena suddenly pops up from the shadows threatening our innocent heroes in the story. \nUnfortunately, the scene was shockingly racial. \nThe audiovisual was too overt to escape my sensibilities. \nThe hyena was black. Hyenas are generally tan or grey. Not black. You could blame it on the lighting but the hyena was black.\n\nIn fact, it appears that the mean hyena was crafted to emulate a black person. Furthermore, its voice over sounded like a black man. \n\nOf course the little children in the audience had no clue they were being brainwashed.\n\nLion King storyline attempted the proverbial Joseph Campbell mono-myth dramatic curve.  They even had the cleansing rain at the end but it was no help to improve the  distasteful bathroom humor.\nLion King failed to sustain the tit-for-tat excitement of Disney yesteryears movies. \n\nA shameless, shamefull racial movie.',
#   'displayName': 'Grandpa',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': True,
#   'createDate': '2019-08-17T17:10:16.509Z',
#   'updateDate': '2019-08-17T17:10:16.509Z',
#   'score': 1.5,
#   'timeFromCreation': '16h ago',
#   'userId': 'cb7cea69-7247-43a5-a243-add6c79266d7',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Grandpa',
#   'userAccountLink': None},
#  {'rating': 'STAR_4',
#   'review': "I didn't like how they changed important scenes from the original movie",
#   'displayName': 'mm',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T17:00:01.879Z',
#   'updateDate': '2019-08-17T17:00:01.879Z',
#   'score': 4,
#   'timeFromCreation': '16h ago',
#   'userId': '71F04656-6CF7-43CD-9FD3-5E5CED5F5043',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'mm',
#   'userAccountLink': None},
#  {'rating': 'STAR_4',
#   'review': 'Beautiful cinematography, Donald Glover and Beyonce are great!',
#   'displayName': 'Andrea H',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T16:03:13.670Z',
#   'updateDate': '2019-08-17T16:03:13.670Z',
#   'score': 4,
#   'timeFromCreation': '17h ago',
#   'userId': '611a80bd-5bdb-4905-bb19-c5f34f341dc6',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Andrea H',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'I didn’t go to see it..... I will!',
#   'displayName': 'Diana Renee',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T15:33:11.452Z',
#   'updateDate': '2019-08-17T15:33:11.452Z',
#   'score': 5,
#   'timeFromCreation': '18h ago',
#   'userId': '0657A075-26F3-44BA-A264-12BAF35FE5FF',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Diana Renee',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'Very realistic.   Beautifully done.',
#   'displayName': 'Jane L',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T15:01:09.499Z',
#   'updateDate': '2019-08-17T15:01:09.499Z',
#   'score': 5,
#   'timeFromCreation': '18h ago',
#   'userId': '670a9a90-1dba-49a0-bbdd-ce45fbe9348d',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Jane L',
#   'userAccountLink': None},
#  {'rating': 'STAR_3',
#   'review': "entertaining, but doesn't live up to its ancestor.",
#   'displayName': 'jacob',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T14:41:14.555Z',
#   'updateDate': '2019-08-17T14:41:14.555Z',
#   'score': 3,
#   'timeFromCreation': '19h ago',
#   'userId': 'C2630603-40ED-4CA0-BA51-AA3C78AF4497',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'jacob',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'The Lion King was so far fantastic movie.!',
#   'displayName': 'Venita',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T14:32:53.541Z',
#   'updateDate': '2019-08-17T14:32:53.541Z',
#   'score': 5,
#   'timeFromCreation': '19h ago',
#   'userId': '5B67062B-8D8D-40A7-9362-BD2DA9A500A8',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Venita',
#   'userAccountLink': None},
#  {'rating': 'STAR_0_5',
#   'review': "The Lion King is a 2019 remake of the 1994 Disney classic The Lion King. The film was directed by Jon Favreau, and stars Donald Glover as Simba and Chiwetel Ejiofor as Scar.\n\nThe film in my opinion is a disgrace to the original film, from the emotionless character expressions to the dreadful and unfitting voice acting.\n\nThe story was basically the same as the original (nearly down to the beat), but for some reason it felt a lot less epic and not nearly as intriguing or emotional.\n\nThe voice acting I found to be stale and dry, from the lack of care in the actors voices to the bland and weary line delivery; one voice actor in particular was Shahadi Wright Joseph as (child) Simba, I found that the performance he gave was really lacking in key areas like emotion and timing.\n\nThe characters were basically just the same as the original, so I don't really have much to say here.\n\nThe animation may be extremely realistic and detailed, but what angers me most is that because of the realism the animals and characters couldn't express as much emotion as they did in the original film.\n\nThe colour scheme was also very dark and grey, which in my opinion takes away from the atmosphere and scale of the film.\n\nThe soundtrack was also a huge let down from the original film, from Beyoncé and Donald Glover's version of Can You Feel the Love Tonight (which takes place in the day) to the addition of Beyoncé's song Spirit.\n\nThe emotion and relationships in the film were also a lot less gripping, especially the relationship between Simba and Mufasa.\n\nThe film I also found to be really bland and uninteresting, but what makes it worse is that the original film was really interesting and had a very strong style to it.\n\nOver all I give it a \n1/10 - would never recommend\n\nA shallow and heartless product which should have never been made.",
#   'displayName': 'Mani P',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T14:31:39.379Z',
#   'updateDate': '2019-08-17T14:31:39.379Z',
#   'score': 0.5,
#   'timeFromCreation': '19h ago',
#   'userId': '977719088',
#   'userRealm': 'RT',
#   'userDisplayName': 'Mani P',
#   'userAccountLink': '/user/id/977719088'},
#  {'rating': 'STAR_3',
#   'review': 'The way the movie built was great but I think the CGI didn’t really capture the emotions of each character compare to original one and all I can see was their mouth open.There are few parts that I like but overall the cartoon is better.',
#   'displayName': 'nmh',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T14:20:03.907Z',
#   'updateDate': '2019-08-17T14:20:03.907Z',
#   'score': 3,
#   'timeFromCreation': '19h ago',
#   'userId': 'DBBF7A07-23AE-40A4-B3E4-B3E9F51DC2B1',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'nmh',
#   'userAccountLink': None},
#  {'rating': 'STAR_4_5',
#   'review': 'Great music. Interesting use of animals. Introduction was poorly filmed, but the remainder of the film had good cinematography, Too long.',
#   'displayName': 'Hector M',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T14:19:18.545Z',
#   'updateDate': '2019-08-17T14:19:18.545Z',
#   'score': 4.5,
#   'timeFromCreation': '19h ago',
#   'userId': '684CF54B-7365-4237-80FA-5CC9488A1BAE',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Hector M',
#   'userAccountLink': None},
#  {'rating': 'STAR_4',
#   'review': 'I really liked this movie',
#   'displayName': 'Tasheka',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T14:07:54.229Z',
#   'updateDate': '2019-08-17T14:07:54.229Z',
#   'score': 4,
#   'timeFromCreation': '19h ago',
#   'userId': 'D16E1AF7-CC5C-4B14-B0EC-372E067ADFF6',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Tasheka',
#   'userAccountLink': None},
#  {'rating': 'STAR_1',
#   'review': 'Why did I waste my money....',
#   'displayName': 'CRYSTAL T',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-17T13:51:20.891Z',
#   'updateDate': '2019-08-17T13:51:20.891Z',
#   'score': 1,
#   'timeFromCreation': '20h ago',
# ...
#   'userDisplayName': 'Paula',
#   'userAccountLink': None},
#  {'rating': 'STAR_4',
#   'review': 'The cinematography is unbelievable.  It looks so real.',
#   'displayName': 'Inessa',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T12:31:57.764Z',
#   'updateDate': '2019-08-09T12:31:57.764Z',
#   'score': 4,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': 'cead4320-0e7e-4f82-909e-561dde02679b',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Inessa',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'I mean the movie was realistic and good that’s why i liked it but I’d recommend a lot of people to watch it',
#   'displayName': 'Jason',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T12:19:24.539Z',
#   'updateDate': '2019-08-09T12:19:24.539Z',
#   'score': 5,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': '12FE8BAF-39EE-4C96-B3CF-23A82FB7DC08',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Jason',
#   'userAccountLink': None},
#  {'rating': 'STAR_3',
#   'review': 'The lack of the animals facial expressions sadly stole very much from the emotion the movie wanted to transfer',
#   'displayName': 'Lara K',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T12:19:10.823Z',
#   'updateDate': '2019-08-09T12:33:50.234Z',
#   'score': 3,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': '978192229',
#   'userRealm': 'RT',
#   'userDisplayName': 'Lara K',
#   'userAccountLink': '/user/id/978192229'},
#  {'rating': 'STAR_2_5',
#   'review': 'Beautiful imagery but the movie felt somewhat flat and unnecessary. Also the best songs were too short.',
#   'displayName': None,
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T12:07:18.232Z',
#   'updateDate': '2019-08-09T12:07:18.232Z',
#   'score': 2.5,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': '906935755',
#   'userRealm': 'RT',
#   'userDisplayName': None,
#   'userAccountLink': '/user/id/906935755'},
#  {'rating': 'STAR_4',
#   'review': 'The movie was different than the cartoon. It was very realistic. The graphics were excellent.',
#   'displayName': 'Donna',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T11:58:30.576Z',
#   'updateDate': '2019-08-09T11:58:30.576Z',
#   'score': 4,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': '4812d8da-d430-40f5-8667-d9025ae805f7',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Donna',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'Great to see on the big screen. Liked that it followed the classic story line.',
#   'displayName': 'Amy',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T11:50:39.819Z',
#   'updateDate': '2019-08-09T11:50:39.819Z',
#   'score': 5,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': '8a1db743-8e1d-41bd-b231-0ee8a7101a60',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Amy',
#   'userAccountLink': None},
#  {'rating': 'STAR_4',
#   'review': 'Very good version of the original story',
#   'displayName': 'Rodrigo',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T11:25:16.570Z',
#   'updateDate': '2019-08-09T11:25:16.570Z',
#   'score': 4,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': 'BEA0A96C-BCD4-4408-A75C-43F993478EA5',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Rodrigo',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'After a few minutes, I felt like the animals were real. Great computer work. Fun movie!',
#   'displayName': 'Judy',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T11:13:05.270Z',
#   'updateDate': '2019-08-09T11:13:05.270Z',
#   'score': 5,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': 'dffb7015-0b55-4689-b1b4-af09eb18f0e2',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Judy',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'Beautifully done!  Everything was so realistic.....down to the breathing  and stars and the dust kicked up by simba and nala running.   Music was wonderful.....we would see it again!',
#   'displayName': 'Susan',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T10:17:49.942Z',
#   'updateDate': '2019-08-09T10:17:49.942Z',
#   'score': 5,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': 'a97fe649-a208-4e94-b6cd-25a7ec70edae',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Susan',
#   'userAccountLink': None},
#  {'rating': 'STAR_1_5',
#   'review': 'Same exact movie almost frame for frame. Worse singing and hot as funny',
#   'displayName': 'Matt',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T10:13:55.879Z',
#   'updateDate': '2019-08-09T10:13:55.879Z',
#   'score': 1.5,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': 'cbe7c0f9-9c09-4065-91c9-5af891222667',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Matt',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'One of the best movies Ive ever seen.  Very well done!!',
#   'displayName': 'Rebecca B',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T09:38:52.423Z',
#   'updateDate': '2019-08-09T09:38:52.423Z',
#   'score': 5,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': '55848c02-afdb-4a93-970d-3627f11f959a',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Rebecca B',
#   'userAccountLink': None},
#  {'rating': 'STAR_3_5',
#   'review': "It was stunningly beautiful and well done. My only complaint is that I wish they had more fun with it and branched out from the original a little. It was TOO much like the original. I mean, yeah, the original was absolutely perfect, but that's the point. If a movie is perfect, then a remake needs to be good in its own way, don't just copy it. I would've loved to see some more backstory on Scar and maybe some of his and Mufasa's childhood. That would have been amazing. Other than that, it was good!",
#   'displayName': 'Rachel A',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T09:37:08.861Z',
#   'updateDate': '2019-08-09T09:37:08.861Z',
#   'score': 3.5,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': '977445567',
#   'userRealm': 'RT',
#   'userDisplayName': 'Rachel A',
#   'userAccountLink': '/user/id/977445567'},
#  {'rating': 'STAR_2',
#   'review': 'expected more. cut out a lot of things.',
#   'displayName': 'CeCeMarie 💜\nCeCeMarie',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T09:28:42.162Z',
#   'updateDate': '2019-08-09T09:28:42.162Z',
#   'score': 2,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': '49E37CE8-899A-472C-A91E-D7E2F56F4FFC',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'CeCeMarie 💜\nCeCeMarie',
#   'userAccountLink': None},
#  {'rating': 'STAR_4',
#   'review': 'I really liked it I really thought some of the scenes were done really well and the music I thought was just as good as the cartoon, like I really liked the Hakuna Matata scene and the Can you feel the love tonight I though those both sounded really well!!!!  Overall I really liked it for a Disney remake the scenes were more intense than the cartoon especially at the end when Simba was fighting Scar!!',
#   'displayName': 'Drew',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T09:13:14.863Z',
#   'updateDate': '2019-08-09T09:13:14.863Z',
#   'score': 4,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': '9cdba29f-26eb-44c5-9d1e-3b8323390a15',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Drew',
#   'userAccountLink': None},
#  {'rating': 'STAR_3',
#   'review': 'Technically beautiful, but emotionally flat and lacking the energy and fun of the original. My daughter loved it though, so what do I know? LOL',
#   'displayName': 'MovieNerdBen',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T08:12:39.218Z',
#   'updateDate': '2019-08-09T08:12:39.218Z',
#   'score': 3,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': '98A92FDA-4AAA-45ED-BB92-7477097106C1',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'MovieNerdBen',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'I enjoyed the whole movie. It took me back to 1994, when Lion King became my favorite movie. Although it had different scripts (some added, some removed), the remake was awesome.',
#   'displayName': 'Lissette T',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T08:06:55.694Z',
#   'updateDate': '2019-08-09T08:06:55.694Z',
#   'score': 5,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': '03ABAEDF-8D6A-47E1-B83A-79F2288327A8',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Lissette T',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'It was ahhhhhmazing!!!! There were times I wanted to take my phone out to take a picture it seemed so real. Absolutely loved it!!!',
#   'displayName': 'Lora',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T05:55:07.604Z',
#   'updateDate': '2019-08-09T05:55:07.604Z',
#   'score': 5,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': '7246C5FC-F9D7-4C93-80ED-19A81A9E253F',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Lora',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'Loved the movie!! It was great!!',
#   'displayName': 'Rachel J',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T05:11:38.076Z',
#   'updateDate': '2019-08-09T05:11:38.076Z',
#   'score': 5,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': 'E6FCDE5C-D042-424D-866F-FE86FE7FBA9C',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Rachel J',
#   'userAccountLink': None},
#  {'rating': 'STAR_4',
#   'review': 'I thought it was a very cute movie for kids with a good message. My 7 and 8 year old granddaughters just loved it.\n',
#   'displayName': 'terri w',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T05:03:25.718Z',
#   'updateDate': '2019-08-09T05:03:25.726Z',
#   'score': 4,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': '978191959',
#   'userRealm': 'RT',
#   'userDisplayName': 'terri w',
#   'userAccountLink': '/user/id/978191959'},
#  {'rating': 'STAR_2',
#   'review': 'It started out with some awesome scenery and shots of African wildlife.  However, the storytelling was labored and too predictable.  When you have an epic tale like Lion King, you cant just let it play out without an added point of interest either in the storyline or the characters.   I found the characters rather bland. Simba is not really resolving his feelings of guilt and the Hakuna Matata song does little to get the message across that a positive outlook can change anything.  Scar is given more screen time than necessary and the final battle between Simba and Scar goes on for far too long.  In fact long enough for my 12 year old grandson to start fidgeting and checking his watch to see when the end would come.  Nala is forgettable and so are most of the other characters with perhaps the exception of Zazu, the dodo bird.  The music left me cold and did nothing to bring back memories of the unforgettable live musical I so loved and enjoyed.',
#   'displayName': 'Hanny',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T05:02:44.130Z',
#   'updateDate': '2019-08-11T03:50:30.480Z',
#   'score': 2,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': 'ab893df6-7875-4786-8543-b5b57306fb38',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Hanny',
#   'userAccountLink': None},
#  {'rating': 'STAR_4',
#   'review': 'I took my 8 year old grandson. We both enjoyed the movie. I had read that it wasnt very good because the animals did not display emotion. This is true, but it did not stop us from enjoying the story.',
#   'displayName': 'Diane O',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T05:02:28.837Z',
#   'updateDate': '2019-08-09T05:02:28.837Z',
#   'score': 4,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': 'b49fd18e-d707-4554-9f51-0e6fecf2be96',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Diane O',
#   'userAccountLink': None},
#  {'rating': 'STAR_3',
#   'review': 'The animated version is still number one.  All the songs sounded rushed.  Very few songs were equal to the animated version.',
#   'displayName': 'nrc',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T04:49:25.530Z',
#   'updateDate': '2019-08-09T04:49:25.530Z',
#   'score': 3,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': 'F3D2D151-E490-4ED6-AEE2-87638DBDF8DF',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'nrc',
#   'userAccountLink': None},
#  {'rating': 'STAR_5',
#   'review': 'Wonderful movie. I love this movie with the real animals.',
#   'displayName': 'Pat',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T04:39:35.903Z',
#   'updateDate': '2019-08-09T04:39:35.903Z',
#   'score': 5,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': '88e4286e-228e-47dd-8f65-97bff464b157',
#   'userRealm': 'Fandango',
#   'userDisplayName': 'Pat',
#   'userAccountLink': None},
#  {'rating': 'STAR_3',
#   'review': 'My 3 stars is for the special effects alone. It was cool to see one of my favorite Disney movies come to life. I just hate they didn’t make anything new or fresh about it. The songs were worse, the punchlines did not land and it felt lazy. Really wish they would have added new songs, new story lines and better singing. ',
#   'displayName': None,
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T04:35:27.259Z',
#   'updateDate': '2019-08-09T04:35:49.095Z',
#   'score': 3,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': '937722524',
#   'userRealm': 'RT',
#   'userDisplayName': None,
#   'userAccountLink': '/user/id/937722524'},
#  {'rating': 'STAR_2',
#   'review': 'By trying to be realistic the movie loses its charm and impact',
#   'displayName': 'JAde Amber B',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-09T04:34:30.079Z',
#   'updateDate': '2019-08-09T04:34:30.079Z',
#   'score': 2,
#   'timeFromCreation': 'Aug 09, 2019',
#   'userId': '904345406',
#   'userRealm': 'RT',
#   'userDisplayName': 'JAde Amber B',
#   'userAccountLink': '/user/id/904345406'},
#  ...]

# %%
#Save the file in json format on your system.
import json

with open("Lion_King_Review.json", "w") as write_file:
    json.dump(all_reviews, write_file)

# %%
#Read the json file from the system.

reviews_data= pd.read_json('Lion_King_Review.json')

# %%
#check the top 3 rows of the dataset.

reviews_data.head(3)
# Out:
#                  createDate  \
# 0  2019-08-18T08:54:30.664Z
# 1  2019-08-18T08:03:49.380Z
# 2  2019-08-18T07:13:32.422Z
#
#                                      displayImageUrl displayName  \
# 0                                               None    Joanne H
# 1  https://graph.facebook.com/v3.3/594379764/picture   Frankie C
# 2                                               None      jaycee
#
#    hasProfanity  hasSpoilers  isSuperReviewer  isVerified  rating  \
# 0         False        False            False        True  STAR_5
# 1         False        False            False       False  STAR_5
# 2         False        False            False       False  STAR_5
#
#                                               review  score timeFromCreation  \
# 0  I liked most that the animation made the anima...    5.0          31m ago
# 1         Amazing! So realistic and incredible music    5.0           1h ago
# 2  Classic. Good remake. Loved it. Glover was out...    5.0           2h ago
#
#                  updateDate     userAccountLink userDisplayName  \
# 0  2019-08-18T08:54:30.890Z                None        Joanne H
# 1  2019-08-18T08:03:49.380Z  /user/id/871398953       Frankie C
# 2  2019-08-18T07:13:32.422Z                None          jaycee
#
#                                  userId userRealm
# 0  2c73ed20-5b9f-41b3-a4fd-8dd3ff8bb20a  Fandango
# 1                             871398953        RT
# 2  DD2453B0-37CE-4B47-A099-D15378FC310E  Fandango

# %%
#Check the shape of the dataset.

reviews_data.shape
# Out:
# (3000, 16)

# %%
#Saving the dataframe in CSV file format.

reviews_data.to_csv('Lion_King_Review.csv')

# %% [markdown]
# This concludes the data collection part. I will load the saved file ("Lion_King_Review.csv") in the next sheet and will perform pre processings and EDA steps there.
